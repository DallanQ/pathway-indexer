# %% [markdown]
# # Parse the information of ACC

# %% [markdown]
# Parse the information from [Acc Site](https://missionaries.prod.byu-pathway.psdops.com/ACC-site-index) to a CSV file.

# %%
import requests
import json
from bs4 import BeautifulSoup, Tag
import csv

from typing import Any, cast
import re

# %% [markdown]
# here we set the general variables

# %%
parser = "html.parser"
header = 'span[style="font-size:18.0pt"]'
sub_header = "b > i"
link = "a"
text = "a > span"

# %% [markdown]
# with this function we will clean our data, delete the weird characters and the empty spaces.

# %%
# clean function
def clean(text: Any) -> str:
    """Convert text to a string and clean it."""
    if text is None:
        return ""
    if isinstance(text, Tag):
        text = text.get_text()
    if not isinstance(text, str):
        text = str(text)
    """Replace non-breaking space with normal space and remove surrounding whitespace."""
    text = text.replace(" ", " ").replace("\u200b", "").replace("\u200a", " ")
    text = re.sub(r"(\n\s*)+\n", "\n\n", text)
    text = re.sub(r" +\n", "\n", text)
    text = re.sub(r"\r\n", " ", text)
    return cast(str, text.strip())

# %% [markdown]
# The `get_data` function will get the data from the website and parse it to a rows list.

# %%
def get_data(soup: Any) -> list:
    """
    Get the data from the soup object.
    """
    cur_header = None
    cur_sub_header = None
    rows = []  # header, subheader, title, url

    elems = soup.select("p.MsoNormal")

    for elem in elems:
        if elem.select(header):
            header_text = elem.select(header)[0].text
            cur_header = clean(header_text)
            cur_sub_header = None
        elif elem.select(sub_header):
            sub_header_text = elem.select(sub_header)[0].text
            cur_sub_header = clean(sub_header_text)
        elif elem.select(link):
            link_text = elem.select(link)[0].get_attribute_list("href")[0]
            text_text = elem.select(text)[0].text

            # save the row
            rows.append(
                [cur_header, cur_sub_header, clean(text_text), clean(link_text)]
            )

    return rows

# %% [markdown]
# ## Data from ACC Site Index

# %%
url1 = "https://missionaries.prod.byu-pathway.psdops.com/ACC-site-index"

response1 = requests.get(url1)

soup1 = BeautifulSoup(response1.content, parser)

# %%
data1 = get_data(soup1)

print(json.dumps(data1, indent=2))
# Out:
# [
#   [
#     "Area Coordination (For ACMs Only)",
#     "ACC Council",
#     "ACM Council Agendas",
#     "https://office365lds.sharepoint.com/sites/BYU-PWAreaCoordination/SitePages/ACM-Council-Agendas.aspx#:~:text=Upcoming%20Agendas"
#   ],
#   [
#     "Block",
#     null,
#     "International Area Transitioning to Block a Guide.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/International-Area-Transitioning-to-Block-a-Guide"
#   ],
#   [
#     "Block",
#     null,
#     "PathwayConnect Curriculum and Block.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/PathwayConnect-Curriculum-and-Block"
#   ],
#   [
#     "Block",
#     null,
#     "PC 103 Block Pilot Spring 2022.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/PC-103-Block-Pilot-Spring-2022"
#   ],
#   [
#     "Missionary Processes",
#     "Vetting ACMs",
#     "ACM Vetting Recommendation Instructions.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/ACM-Vetting-Recommendation-Instructions"
#   ],
#   [
#     "Missionary Processes",
#     "Vetting New Missioanries",
#     "Vetting New Missionary Instructions.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Vetting-New-Missionary-Instructions"
#   ],
#   [
#     "Missionary Software & Uses",
#     "CRM",
#     "Creating a New Ticket.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Creating-a-New-Ticket"
#   ],
#   [
#     "Missionary Software & Uses",
#     "CRM",
#     "CRM Checking Ticket Results.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/CRM-Checking-Ticket-Results"
#   ],
#   [
#     "Missionary Software & Uses",
#     "CRM",
#     "How to Create a New Ticket",
#     "https://missionaries.prod.byu-pathway.psdops.com/Creating-a-New-Ticket"
#   ],
#   [
#     "Missionary Software & Uses",
#     "CRM",
#     "Student Issue Escalation Process.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Student-Issue-Escalation-Process"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Closing a Site.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Closing-a-Site"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Creating a New Site in PATH.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Creating-a-New-Site-in-PATH"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Path Reorg.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Path-Reorg"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Accessing Your Student List in PATH.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Accessing-Your-Student-List-in-PATH"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Adjusting for Daylight Savings Time.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Adjusting-for-Daylight-Savings-Time"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Approving Units-Stakes for Virtual Locations.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Approving-Units-Stakes-for-Virtual-Locations"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Assign a Role to a Missionary.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Assign-a-Role-to-a-Missionary"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Assign the Church Unit Detail Role.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Assign-the-Church-Unit-Detail-Role"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Assigning Missionaries to a Group.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Assigning-Missionaries-to-a-Group"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Assigning Students from the Unassigned List.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Assigning-Students-from-the-Unassigned-List"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Check a Learner's ELA Scores.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Check-a-Learner's-ELA-Scores"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Closing or Deprecating a Group.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Closing-or-Deprecating-a-Group"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Creating a New Group.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Creating-a-New-Group"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Designating Programs Active or Hidden.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Designating-Programs-Active-or-Hidden"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Email Data Privacy.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Email-Data-Privacy"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Find a Learner's Enrollment Information.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Find-a-Learner's-Enrollment-Information"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Find a Learner's ID Number.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Find-a-Learner's-ID-Number"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Find a Learner's Personal Information.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Find-a-Learner's-Personal-Information"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Find a Learner's Tuition Payment and Balance.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Find-a-Learner's-Tuition-Payment-and-Balance"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Find a Student's Contact Information.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Find-a-Student-Contact-Information"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Find a Student's ID Number.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Find-a-Students-ID-Number"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Find Student Information.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Find-Student-Information"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Find Student Personal Information.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Find-Student-Personal-Information"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Find Tuition Balance and Payments.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Find-Tuition-Balance-and-Payments"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Finding Learner Information EC3.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Finding-Learner-Information-EC3"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Finding Student Information in PATH",
#     "https://missionaries.prod.byu-pathway.psdops.com/Finding-Student-Information-in-PATH%E2%80%8B"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Finding Students with Duplicate Path Accounts.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Finding-Students-with-Duplicate-Path-Accounts"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Finding Your Location in PATH EC3.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Finding-Your-Location-in-PATH-EC3"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Finding Your Location in PATH.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Finding-Your-Location-in-PATH"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "How to Identify PC Enrolled Students That Should be in C&D.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-to-Identify-PC-Enrolled-Students-That-Should-be-in-C&D"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "How to Log into PATH.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-to-Log-into-PATH"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Impersonating a Student in PC.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Impersonating-a-Student-in-PC"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Locate a Student's Enrollment Record.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Locate-a-Student's-Enrollment-Record"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Locate Learner Information.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Locate-Learner-Information"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Modify a Student Name for a Completion Certificate.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Modify-a-Student-Name-for-a-Completion-Certificate"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Monitoring Missionary End Dates in PATH.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Monitoring-Missionary-End-Dates-in-PATH"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Monitoring Student Progress.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Monitoring-Student-Progress"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Moving a Missionary to a New Location.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Moving-a-Missionary-to-a-New-Location"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Organizing PATH for your area.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Organizing-PATH-for-your-area"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Overview of Location Details Page.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Overview-of-Location-Details-Page"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "PATH Group Naming Convention.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/PATH-Group-Naming-Convention"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "PATH Overview.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/PATH-Overview"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "PATH Walkthrough.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/PATH-Walkthrough"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "PC - Finding Student Information.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/PC-Finding-Student-Information"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Printing an Individual Certificate of Completion.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Printing-an-Individual-Certificate-of-Completion"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Restructuring Your Area in PATH.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Restructuring-Your-Area-in-PATH"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Send a Group Email.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Send-a-Group-Email"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Student Finance Information.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Student-Finance-Information"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Student Online Enrollment Information .pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Student-Online-Enrollment-Information"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Student Transfer FAQ.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Student-Transfer-FAQ"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Transferring a Student to a Different Area.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Transferring-a-Student-to-a-Different-Area"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Transferring a Student to a Different Location.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Transferring-a-Student-to-a-Different-Location"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Transferring a Student to a Different Program.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Transferring-a-Student-to-a-Different-Program"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Transferring a Student within a Location.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Transferring-a-Student-within-a-Location"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Understanding the Groups Page EC3.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Understanding-the-Groups-Page-EC3"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Updating Group Information.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Updating-Group-Information"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Updating Personal Information.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Updating-Personal-Information"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Using the PATH Search Feature EC3.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Using-the-PATH-Search-Feature-EC3"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Using the Site Location Directory.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Using-the-Site-Location-Directory"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Verify a Learner's Church Member Status.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Verify-a-Learner's-Church-Member-Status"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Verify a Student's Church Membership Status.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Verify-a-Student's-Church-Membership-Status"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Verify Completion of a Background Check.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Verify-Completion-of-a-Background-Check"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "Verify Member Recordl Number (MRN).pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Verify-Member-Recordl-Number-MRN"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "View a Student's English Pre-Assessment.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/View-a-Student's-English-Pre-Assessment"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "View Scholarships Received.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/View-Scholarships-Received"
#   ],
#   [
#     "Missionary Software & Uses",
#     "PATH for Area Coordination Missionaries (ACMs)",
#     "What is a Default Group.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/What-is-a-Default-Group"
#   ],
#   [
#     "Missionary Software & Uses",
#     "Power BI",
#     "Basic Navigation of Power BI.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Basic-Navigation-of-Power-BI"
#   ],
#   [
#     "Missionary Software & Uses",
#     "Power BI",
#     "Check Enrollment Trends.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Check-Enrollment-Trends"
#   ],
#   [
#     "Missionary Software & Uses",
#     "Power BI",
#     "Checking Enrollment Trends.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Check-Enrollment-Trends"
#   ],
#   [
#     "Missionary Software & Uses",
#     "Power BI",
#     "Download a Report.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Download-a-Report"
#   ],
#   [
#     "Missionary Software & Uses",
#     "Power BI",
#     "Finding & Using PowerBI Reports.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Finding-&-Using-PowerBI-Reports"
#   ],
#   [
#     "Missionary Software & Uses",
#     "Power BI",
#     "Focus Mode.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Focus-Mode"
#   ],
#   [
#     "Missionary Software & Uses",
#     "Power BI",
#     "How to Find Power BI Reports 3.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-to-Find-Power-BI-Reports-3"
#   ],
#   [
#     "Missionary Software & Uses",
#     "Power BI",
#     "How to Use the Filter Menu.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-to-Use-the-Filter-Menu"
#   ],
#   [
#     "Missionary Software & Uses",
#     "Power BI",
#     "Monitor HJG Applications.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Monitor-HJG-Applications"
#   ],
#   [
#     "Missionary Software & Uses",
#     "Power BI",
#     "Monitor Missionary End Dates in Power BI.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Monitor-Missionary-End-Dates-in-Power-BI"
#   ],
#   [
#     "Missionary Software & Uses",
#     "Power BI",
#     "Power BI Training.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Power-BI-Training"
#   ],
#   [
#     "Missionary Software & Uses",
#     "Power BI",
#     "PowerBI Reports Overview.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/PowerBI-Reports-Overview"
#   ],
#   [
#     "Missionary Software & Uses",
#     "Power BI",
#     "Prepare Excel Sheets for Basic Filtering.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Prepare-Excel-Sheets-for-Basic-Filtering"
#   ],
#   [
#     "Missionary Software & Uses",
#     "Power BI",
#     "Reset Filters.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Reset-Filters"
#   ],
#   [
#     "Missionary Software & Uses",
#     "Power BI",
#     "Use Additional Filters.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Use-Additional-Filters"
#   ],
#   [
#     "Missionary Software & Uses",
#     "Technical Support",
#     "2023 ELA Pilot.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/2023-ELA-Pilot"
#   ],
#   [
#     "Missionary Software & Uses",
#     "Troubleshooting",
#     "Check to See if a BYU-Pathway Worldwide System is Down",
#     "https://office365lds.sharepoint.com/sites/BYU-PathwayTechnicalSupport/SitePages/System-Status.aspx?xsdata=&sdata=QnlHMGZ5SXd5enNYRUM3bktoa0lNZ0Z3VE84Yk9EK0hhYmhLakM5aXVhcz0%3D&CT=1715195813843&OR=OWA-NT-Mail&CID=a0a1c942-2326-f38f-5387-ba456eb48a6a&clickParams=eyJYLUFwcE5hbWUiOiJNaWNyb3NvZnQgT3V0bG9vayBXZWIgQXBwIiwiWC1BcHBWZXJzaW9uIjoiMjAyNDA0MTkwMDcuMzUiLCJPUyI6Ik1hYyBPUyBYIHVuZGVmaW5lZCJ9"
#   ],
#   [
#     "Missionary Support and Training",
#     "Missionary Motivations",
#     "Temple Make and Keep Covenants.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Temple-Make-and-Keep-Covenants"
#   ],
#   [
#     "Policies",
#     null,
#     "BYU Pathway Worldwide Unapproved Locations.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/BYU-Pathway-Worldwide-Unapproved-Locations"
#   ],
#   [
#     "Policies",
#     null,
#     "Policy Assistant ACM Role.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Policy-Assistant-ACM-Role"
#   ],
#   [
#     "Policies",
#     null,
#     "Policy BYU Pathway Gathering Standards.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Policy-BYU-Pathway-Gathering-Standards"
#   ],
#   [
#     "Policies",
#     null,
#     "Policy CDOL Access.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Policy-CDOL-Access"
#   ],
#   [
#     "Policies",
#     null,
#     "Policy Employees Serving As BYUPW Service Missionary.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Policy-Employees-Serving-As-BYUPW-Service-Missionary"
#   ],
#   [
#     "Policies",
#     null,
#     "Policy Exception to Enroll With Outstanding Balances.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Policy-Exception-to-Enroll-With-Outstanding-Balances"
#   ],
#   [
#     "Policies",
#     null,
#     "Policy Executive Secretaries & Communication.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Policy-Executive-Secretaries-&-Communication"
#   ],
#   [
#     "Policies",
#     null,
#     "Policy International Student Transfers.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Policy-International-Student-Transfers"
#   ],
#   [
#     "Policies",
#     null,
#     "Policy Issue Zoom Licensed Accounts.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/ACC%20Documents%20Policy%20Issue%20Zoom%20Licensed%20Accounts"
#   ],
#   [
#     "Policies",
#     null,
#     "Policy Missionary Badge Policy.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Policy-Missionary-Badge-Policy"
#   ],
#   [
#     "Policies",
#     null,
#     "Policy New Admission Deadlines.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Policy-New-Admission-Deadlines"
#   ],
#   [
#     "Policies",
#     null,
#     "Policy PATH EnglishConnect Naming Convention for Groups.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Policy-PATH-EnglishConnect-Naming-Convention-for-Groups"
#   ],
#   [
#     "Policies",
#     null,
#     "Policy PATH Naming Convention for Groups.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Policy-PATH_Naming-Convention-for-Groups"
#   ],
#   [
#     "Policies",
#     null,
#     "Policy Service Missionary Name Badges.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Policy-Service-Missionary-Name-Badges"
#   ],
#   [
#     "Policies",
#     null,
#     "Policy Student Grievance Against Missionary Public Viewing.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Policy-Student-Grievance-Against-Missionary-Public-Viewing"
#   ],
#   [
#     "Policies",
#     null,
#     "Policy Student Late Fee Policy.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Policy-Student-Late-Fee-Policy"
#   ]
# ]

# %% [markdown]
# Now we will save our data into the `acc_site.csv` file.

# %%
with open("acc_site.csv", "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(data1)

# %% [markdown]
# # Missionary Services Site Index

# %%
url2 = "https://missionaries.prod.byu-pathway.psdops.com/missionary-services-site-index"

response2 = requests.get(url2)

soup2 = BeautifulSoup(response2.content, parser)

# %%
data2 = get_data(soup2)

print(json.dumps(data2, indent=2))
# Out:
# [
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "2024_Service Missionaries Flyer.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/2024_Service-Missionaries-Flyer"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Apply For and Check Status of HJG Scholarship.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Apply-For-and-Check-Status-of-HJG-Scholarship"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Area Manager Assignments.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Area-Manager-Assignments"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Area Structure and Communication.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Area-Structure-and-Communication"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "BYU-Pathway History-Full.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/BYU-Pathway-History-Full"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "BYU-Pathway History-Short.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/BYU-Pathway-History-Short"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "BYU-Pathway Worldwide History.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/BYU-Pathway-Worldwide-History"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "BYU-PW Strategy.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/BYU-Pathway-Strategy"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Certificate-First Approach.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Certificate-First-Approach"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Check Student History for Past Grades.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Check-Student-History-for-Past-Grades"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "CHINESE CSM Application Oct2021.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/CHINESE-CSM-Application-Oct2021"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Church HR Annual Workforce Training.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Church-HR-Annual-Workforce-Training"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Create a Relationship with Your Mentor.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Create-a-Relationship-with-Your-Mentor"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Defining Characteristics.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Defining-Characteristics"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "ENGLISH CSM Application Oct2021.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/ENGLISH%20CSM%20Application%20Oct2021"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Ensign College Overview.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Ensign-College-Overview"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Finding the Correct BYU-Pathway Application.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Finding-the-Correct-BYU-Pathway-Application"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "FRENCH CSM Application Oct2021.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/FRENCH-CSM-Application-Oct2021"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "GERMAN CSM Application Oct2021.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/GERMAN-CSM-Application-Oct2021"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Guidelines for Communicating with Students or Learners.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Guidelines-for-Communicating-with-Students-or-Learners"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "How a Student Withdraws from a Program PC or EC3.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-a-Student-Withdraws-from-a-Program-PC-or-EC3"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "How Students Find Their Mentor.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-Students-Find-Their-Mentor"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "ITALIAN CSM Application Oct2021.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/ITALIAN-CSM-Application-Oct2021"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Japanese CSM Application Oct2021.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Japanese-CSM-Application-Oct2021"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "KOREAN CSM Application Oct2021.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/KOREAN-CSM-Application-Oct2021"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Mission Statement.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Mission-Statement"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Navigate the Missionary Services Website on Desktop.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Navigate-the-Missionary-Services-Website-on-Desktop"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Navigate the Missionary Services Website on Mobile.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Navigate-the-Missionary-Services-Website-on-Mobile"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Peer Mentor Group Assignments.xlsx",
#     "https://missionaries.prod.byu-pathway.psdops.com/Peer-Mentor-Group-Assignments.xlsx"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Policy - Missionary Dress & Grooming policy.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Policy-Missionary-Dress-&-Grooming-policy"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Policy-PATH_Naming Convention for Groups.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Policy-PATH_Naming-Convention-for-Groups"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "PORTUGUESE CSM Application Oct2021.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/PORTUGUESE-CSM-Application-Oct2021"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Restrictions for Applying to BYUPW.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Restrictions-for-Applying-to-BYUPW"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "RUSSIAN CSM Application Oct2021.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/RUSSIAN-CSM-Application-Oct2021"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Scholarship Information.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Scholarship-Information"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Service Missionaries-2.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Service-Missionaries-2"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "SPANISH CSM Application Oct2021.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/SPANISH-CSM-Application-Oct2021"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "TAGALOG CSM Application Oct2021.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/TAGALOG-CSM-Application-Oct2021"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Three-Year Degree.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Three-Year-Degree"
#   ],
#   [
#     "BYU-Pathway Worldwide",
#     "BYU-Pathway Worldwide Overview",
#     "Updating Group Information.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Updating-Group-Information"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Getting Started",
#     "Different Places for my Courses",
#     "https://resourcecenter.byupathway.org/different-places-for-my-courses"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Getting Started",
#     "Quick Start:\u00a0 Using Canvas on a Web Browser",
#     "https://resourcecenter.byupathway.org/faqs/canvas/using-canvas-a-quick-start-guide"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Getting Started",
#     "Quick Start:\u00a0 Using Canvas on the Mobile App",
#     "https://resourcecenter.byupathway.org/quick-start-using-canvas-on-mobile-app"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Getting Started",
#     "Using Canvas Quick Start Guide",
#     "https://content.byui.edu/file/c529b6cc-a70b-4a94-9872-01f35548d87d/117/Logging%20in%20to%20I-Learn%20and%20Getting%20Around%20\u2013%20a%20Quick%20Start%20Guide.pdf"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Getting Started",
#     "What is Canvas?",
#     "https://resourcecenter.byupathway.org/what-is-canvas"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Communication",
#     "How do I contact a grader?",
#     "https://resourcecenter.byupathway.org/faqs/f03-01"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Communication",
#     "How do I read announcements in Canvas?",
#     "https://resourcecenter.byupathway.org/how-to-read-announcements-in-canvas"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Communication",
#     "How do I set up notifications in Canvas?",
#     "https://resourcecenter.byupathway.org/notification-set-up"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Communication",
#     "How do I use my Canvas Inbox?",
#     "https://resourcecenter.byupathway.org/faqs/f03-02"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Completing Work",
#     "How do I complete an assignment using Microsoft 365?",
#     "https://resourcecenter.byupathway.org/faqs/canvas/how-do-i-complete-an-assignment-using-microsoft-365"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Completing Work",
#     "How do I download an assignment template?",
#     "https://resourcecenter.byupathway.org/faqs/f02-03"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Completing Work",
#     "How do I participate in Discussions in Canvas?",
#     "https://resourcecenter.byupathway.edu/faqs/canvas/discussions-in-canvas"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Completing Work",
#     "How do I see important dates in Canvas?",
#     "https://resourcecenter.byupathway.org/how_to_see_important_dates_in_Canvas"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Completing Work",
#     "How do I sign in to Microsoft 365 on a Mobile Device?",
#     "https://resourcecenter.byupathway.org/how-to-sign-in-to-microsoft-365-on-mobile-device"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Completing Work",
#     "How do I submit an assignment in Canvas?",
#     "https://resourcecenter.byupathway.org/faqs/f02-04"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Grades and Feedback",
#     "How do I check what-if grades?",
#     "https://resourcecenter.byupathway.edu/faqs/canvas/how-do-i-check-what-if-grades"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Grades and Feedback",
#     "How do I find my feedback on Math Prep and Writing Prep quizzes?",
#     "https://resourcecenter.byupathway.org/faqs/f02-02"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Grades and Feedback",
#     "How do I find my grade and feedback on an assignment?",
#     "https://resourcecenter.byupathway.org/faqs/f02-01"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Settings",
#     "How do I edit my photo, email, language, and time zone?",
#     "https://resourcecenter.byupathway.org/photo-email-language-time-zone"
#   ],
#   [
#     "Canvas \u2013 Student Questions",
#     "Troubleshooting",
#     "Which Browsers Does Canvas Support",
#     "https://community.canvaslms.com/t5/Canvas-Basics-Guide/What-are-the-browser-and-computer-requirements-for-Instructure/ta-p/66"
#   ],
#   [
#     "Certificates & Degrees",
#     "Application Process",
#     "Preferred Path (byupathway.edu)",
#     "https://www.byupathway.edu/admissions/application-process#preferred-path:~:text=No%20ACT/SAT%20required%20for%20admission"
#   ],
#   [
#     "Certificates & Degrees",
#     "Ecclesiastical Endorsements",
#     "3 Answers to Your Questions about Ecclesiastical Endorsement",
#     "https://www.byupathway.edu/articles/tips/ecclesiastical-endorsement"
#   ],
#   [
#     "Certificates & Degrees",
#     "Ecclesiastical Endorsements",
#     "Ecclesiastical Endorsements.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Ecclesiastical-Endorsements"
#   ],
#   [
#     "Certificates & Degrees",
#     "Online Degree General Information",
#     "Identify BYU-Pathway Portals.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Identify-BYU-Pathway-Portals"
#   ],
#   [
#     "Certificates & Degrees",
#     "Online Degree General Information",
#     "Understanding Certificates Revised.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Understanding-Certificates-Revised"
#   ],
#   [
#     "Certificates & Degrees",
#     "Three-Year Degree",
#     "Three-Year Degree Information for Current and Returning Students",
#     "https://www.byupathway.org/three-year-degree-information"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Access the Learner Platform.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Access-the-Learner-Platform"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Access the Learner Portal.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Access-the-Learner-Portal"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Access Your Learner Progress Report.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Access-Your-Learner-Progress-Report"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Accessing Your Learner List.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Accessing-Your-Learner-List"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Autodrop for EC3.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Autodrop-for-EC3"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Companion App Overview.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Companion-App-Overview"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Create an Online Community.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Create-an-Online-Community"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EC3 Application Walkthough.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EC3-Application-Walkthough"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EC3 Flyer for Service Missionaries_Chinese Traditional.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EC3-Flyer-for-Service-Missionaries_Chinese-Traditional"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EC3 Flyer for Service Missionaries_English.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EC3-Flyer-for-Service-Missionaries_English"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EC3 Flyer for Service Missionaries_French .pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EC3-Flyer-for-Service-Missionaries_French"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EC3 Flyer for Service Missionaries_Portuguese.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EC3-Flyer-for-Service-Missionaries_Portuguese"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EC3 Flyer for Service Missionaries_Spanish.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EC3-Flyer-for-Service-Missionaries_Spanish"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EC3 Flyer for Service Missionaries_Ukrainian.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EC3-Flyer-for-Service-Missionaries_Ukrainian"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EC3 Frequently Asked Questions.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EC3-Frequently-Asked-Questions"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EC3 Gathering Procedures.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EC3-Gathering-Procedures"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EC3 Learner Portal Walkthrough.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EC3-Learner-Portal-Walkthrough"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EC3 Learner Profiles.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EC3-Learner-Profiles"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EC3 Participation and Completion Certificates.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EC3-Participation-and-Completion-Certificates"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EC3 Pre-Semester Gathering Agenda.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EC3-Pre-Semester-Gathering-Agenda"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EC3 Pre-Semester Gathering.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EC3-Pre-Semester-Gathering"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EC3 Re-enrollment.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EC3-Re-enrollment"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EC3 Virtual Gathering Best Practices.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EC3-Virtual-Gathering-Best-Practices"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "English Connect 3 Video July 27.mp4",
#     "https://missionaries.prod.byu-pathway.psdops.com/English-Connect-3-Video-July-27.mp4"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EnglishConnect Academic Calendar.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EnglishConnect-Academic-Calendar"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "EnglishConnect3 Common Terms.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/EnglishConnect3-Common-Terms"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Facilitating a Virtual EC3 Gathering.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Facilitating-a-Virtual-EC3-Gathering"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Facilitating an In-Person EC3 Gathering.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Facilitating-an-In-Person-EC3-Gathering"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "First Contact Messages for Learners.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/First-Contact-Messages-for-Learners"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Guidelines for Gatherings with 11-17 yrs old.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Guidelines-for-Gatherings-with-11-17-yrs-old"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Help a Learner with Registration and Enrollment.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Help-a-Learner-with-Registration-and-Enrollment"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Help the Lead Learner.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Help-the-Lead-Learner"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "How a Learner Applies for EnglishConnect 3.pdf",
#     "https://byu-pathway.brightspotcms.com/cms/content/edit.jsp?id=00000191-133d-db08-a3b9-1ffdadd50001&typeId=99ef42fa-b84a-3573-8e5b-015af8a5b9cf"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "How Learners Withdraw.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-Learners-Withdraw"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "How to Issue an EC3 Certificate_.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-to-Issue-an-EC3-Certificate_"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "How to Issue an EnglishConnect 3 Certificate.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-to-Issue-an-EnglishConnect-3-Certificate"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "How to locate stakes and student information.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-to-locate-stakes-and-student-information"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "How to Pay Tuition for EC3.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-to-Pay-Tuition-for-EC3"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Impersonate a Learner to Access.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Impersonate-a-Learner-to-Access"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Lead Learner Lesson Plan Overview.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Lead-Learner-Lesson-Plan-Overview"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Learning Platform Walkthrough.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Learning-Platform-Walkthrough"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Logging into PATH EC3.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Logging-into-PATH-EC3"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "New Learner Visit.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/New-Learner-Visit"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Overview of Location Details Page EC3.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Overview-of-Location-Details-Page-EC3"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Switching to EC3 PATH.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Switching-to-EC3-PATH"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Troubleshoot platform issues.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Troubleshoot-Platform-Issues"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Understand and Help Adult Learners Progress.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Understand-and-Help-Adult-Learners-Progress"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Updating Your Personal Information in PATH EC3.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Updating-Your-Personal-Information-in-PATH-EC3"
#   ],
#   [
#     "EnglishConnect 3 (EC3)",
#     "EnglishConnect 3",
#     "Your Role in the EC3 Gathering.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Your-Role-in-the-EC3-Gathering"
#   ],
#   [
#     "Forms",
#     null,
#     "Student Wellness Help (Form)",
#     "https://forms.office.com/Pages/ResponsePage.aspx?id=s-7mYddfqkquPGHo3rCbeRIoNMRhMxdFtcMsNT065pRUNUVMWFhXMzkwWUNEMjJEOVEzMzlMRzNYWi4u"
#   ],
#   [
#     "Friends of the Church",
#     null,
#     "Give a BOM to friends of the church",
#     "https://www.churchofjesuschrist.org/study/manual/share-the-book-of-mormon-2024/01?lang=eng"
#   ],
#   [
#     "Friends of the Church",
#     null,
#     "Help a Friend Connect with the Missionaries",
#     "https://www.churchofjesuschrist.org/serve/share/connect-with-missionaries?lang=eng"
#   ],
#   [
#     "Gatherings",
#     "Gathering Training and Resources",
#     "Best Practices for Facilitating Virtual Gatherings.pdf",
#     "https://byu-pathway.brightspotcms.com/cms/content/edit.jsp?id=00000191-1346-de5b-a9f9-535eb8220001&typeId=99ef42fa-b84a-3573-8e5b-015af8a5b9cf"
#   ],
#   [
#     "Gatherings",
#     "Gathering Training and Resources",
#     "Best Practices for Virtual Gatherings That Dont Feature Videoconferencing.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Best-Practices-for-Virtual-Gatherings-That-Dont-Feature-Videoconferencing"
#   ],
#   [
#     "Gatherings",
#     "Gathering Training and Resources",
#     "Gathering Procedures (PathwayConnect).pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Gathering-Procedures-PathwayConnect"
#   ],
#   [
#     "Gatherings",
#     "Gathering Training and Resources",
#     "Gathering Procedures for Inviting Friends.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Gathering-Procedures-for-Inviting-Friends"
#   ],
#   [
#     "Gatherings",
#     "Gathering Training and Resources",
#     "PathwayConnect Gathering Procedures.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/PathwayConnect-Gathering-Procedures"
#   ],
#   [
#     "Gatherings",
#     "Gathering Training and Resources",
#     "PC 102 Semester Project Overview.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/PC-102-Semester-Project-Overview"
#   ],
#   [
#     "Gatherings",
#     "Other Gathering Resources",
#     "Improving Your Role in the Gathering",
#     "https://office365lds.sharepoint.com/sites/BYUPW-MissionaryServices/SitePages/SHEP--Improving-Your-Role-in-the-gathering.aspx"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "BYU-Pathway in 30 Seconds.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/BYU-Pathway-in-30-Seconds"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "BYU-Pathway in 7-10 Minutes.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/BYU-Pathway-in-7-10-Minutes"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "BYUPW Interest List.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/BYUPW-Interest-List"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Domestic Quarter Sheets Any Student.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Domestic-Quarter-Sheets-Any-Student"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Domestic Quarter Sheets- Better Job.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Domestic-Quarter-Sheets-Better-Job"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Domestic Quarter Sheets- fresh start.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Domestic-Quarter-Sheets-fresh-start"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Domestic Quarter Sheets-Everyone-can-access-higher-education.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Domestic-Quarter-Sheets-Everyone-can-access-higher-education"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Elders Quorom and Relief Society Presentations.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Elders-Quorom-and-Relief-Society-Presentations"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Email All Adult Members.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Email-All-Adult-Members"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Employment and Self-Reliance Fair.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Employment-and-Self-Reliance-Fair"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Explaining BYUPW to Potential Students.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Explaining-BYUPW-to-Potential-Students"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Firesides and Devotionals.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Firesides-and-Devotionals"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Informe en Fuentes de recursos para li\u0301deres y secretarios de la Iglesia.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Informe-en-Fuentes-de-recursos-para-l\u00edderes-y-secretarios-de-la-Iglesia"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Institutional Handout.pdf .pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Institutional-Handout-"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "institutional-brochure-bi-fold-pdf.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/institutional-brochure-bi-fold-pdf"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Inviting Friends of the Church (No Nonmembers in Group).pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Inviting-Friends-of-the-Church-No-Nonmembers-in-Group"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Inviting Friends of the Church (Nonmembers in Group).pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Inviting-Friends-of-the-Church-Nonmembers-in-Group"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Inviting Friends Who Are Not Members.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Inviting-Friends-Who-Are-Not-Members"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Leader and Clerk Resources Report for Church Leaders.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Leader-and-Clerk-Resources-Report-for-Church-Leaders"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Ministering Through Education.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Ministering-Through-Education"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Presenting at Ward and Stake Council.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Presenting-at-Ward-and-Stake-Council"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Sacrament Meeting Talks.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Sacrament-Meeting-Talks"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Scriptures, Quotes, and Talks About Education.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Scriptures-Quotes-and-Talks-About-Education"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Second Hour Presentation.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Second-Hour-Presentation"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Stake Bishop Council Meeting.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Stake-Bishop-Council-Meeting"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Sunday Visits with Language Wards.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Sunday-Visits-with-Language-Wards"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Sunday Visits with Wards and Stakes.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Sunday-Visits-with-Wards-and-Stakes"
#   ],
#   [
#     "Increasing Awareness",
#     "Increasing Awareness of PathwayConnect",
#     "Ward Bulletin Announcement.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Ward-Bulletin-Announcement"
#   ],
#   [
#     "Institute/Religion",
#     null,
#     "Check for Institute Registration for College Credit.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/institute-for-college-credit"
#   ],
#   [
#     "Institute/Religion",
#     null,
#     "Institute - Religion course requirements for PathwayConnect Students",
#     "https://www.byupathway.edu/policies/catalog/7-01-institute-religion-course-requirements"
#   ],
#   [
#     "Missionary Processes",
#     "When you are finished with your PathwayConnect Service",
#     "International CSM SSM Application Process.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/International-CSM-SSM-Application-Process"
#   ],
#   [
#     "Missionary Processes",
#     "When you are finished with your PathwayConnect Service",
#     "International CSM SSM Application Process Feb2022 Int Application and Extension.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/International-CSM-SSM-Application-Process-Feb2022-Int-Application-and-Extension"
#   ],
#   [
#     "Software Systems",
#     "Troubleshooting",
#     "Check to See if a BYU-Pathway Worldwide System is Down",
#     "https://office365lds.sharepoint.com/sites/BYU-PathwayTechnicalSupport/SitePages/System-Status.aspx?xsdata=&sdata=QnlHMGZ5SXd5enNYRUM3bktoa0lNZ0Z3VE84Yk9EK0hhYmhLakM5aXVhcz0%3D&CT=1715195813843&OR=OWA-NT-Mail&CID=a0a1c942-2326-f38f-5387-ba456eb48a6a&clickParams=eyJYLUFwcE5hbWUiOiJNaWNyb3NvZnQgT3V0bG9vayBXZWIgQXBwIiwiWC1BcHBWZXJzaW9uIjoiMjAyNDA0MTkwMDcuMzUiLCJPUyI6Ik1hYyBPUyBYIHVuZGVmaW5lZCJ9"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "About New Student Visits.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/About-New-Student-Visits"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Academic Planning Tools for PC.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Academic-Planning-Tools-for-PC"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Academic Planning Tools.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Academic-Planning-Tools"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Auto-drop.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Auto-drop"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Best Practices for an In-Person Gathering.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Best-Practices-for-an-In-Person-Gathering"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Block and Instructional TeaFAQ.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Block-and-Instructional-TeaFAQ"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Calculate a Students GPA.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Calculate-a-Students-GPA"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Course Preview Overview.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Course-Preview-Overview"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Explain Auto-drop to Students for PC.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Explain-Auto-drop-to-Students-for-PC"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Explain the Block Schedule.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Explain-the-Block-Schedule"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Forming Team Project Groups for PC 102.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Forming-Team-Project-Groups-for-PC-102"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "How Students Choose Their Certificate.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-Students-Choose-Their-Certificate"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "How Students Print Their Certificate of Completion.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-Students-Print-Their-Certificate-of-Completion"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "How Students Repeat Courses.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-Students-Repeat-Courses"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Ideas if a lead student doesn't show.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Ideas-if-a-lead-student-doesn't-show"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Instructional Teams.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Instructional-Teams"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Learn About PC 101.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Learn-About-PC-101"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Learn About PC 102.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Learn-About-PC-102"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Learn About PC 103.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Learn-About-PC-103"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Navigating the Student Portal.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/navigating-the-student-portal"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "New Student Orientation/New Student Checklist",
#     "https://www.byupathway.edu/new-student-orientation-pathwayconnect?pk_campaign=NSU&pk_kwd=-4.2&pk_source=email&pk_medium=26-03-2024&pk_content=03"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "New Student Visits - Tracker.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/New-Student-Visits-Tracker"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "New Student Visits.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/New-Student-Visits"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "PathwayConnect Common Terms.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/PathwayConnect-Common-Terms"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "PC 101 Block Lead Student Sign-Up Sheet.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/PC-101-Block-Lead-Student-Sign-Up-Sheet"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "PC 103 Block LS Sign-Up Sheet Fillable.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/PC-103-Block-LS-Sign-Up-Sheet-Fillable"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "PC Application Process.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/PC-Application-Process"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "PC Application Walkthrough.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/PC-Application-Walkthrough"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Playing Hymns in a Virtual Gathering.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Playing-Hymns-in-a-Virtual-Gathering"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Shepherding Team Project Groups.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Shepherding-Team-Project-Groups"
#   ],
#   [
#     "PathwayConnect (PC)",
#     "PathwayConnect General Information",
#     "Students Visiting Another Gathering.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Students-Visiting-Another-Gathering"
#   ],
#   [
#     "Scholarships & Tuition Discounts",
#     "Scholarships Available to Students",
#     "Scholarships for PathwayConnect.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Scholarships-for-PathwayConnect"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "BYU-Idaho Tutoring Services.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/BYU-Idaho-Tutoring-Services"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "Create a Church Account for Friends of the Church.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Create-a-Church-Account-for-Friends-of-the-Church"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "Evaluating Your Gathering.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Evaluating-Your-Gathering"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "Explain Gospel Resources.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Explain-Gospel-Resources"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "Helping Students Overcome Obstacles.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Helping-Students-Overcome-Obstacles"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "Helping Students Register for Next Term.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Helping-Students-Register-for-Next-Term"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "Helping Students Select a Certificate.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Helping-Students-Select-a-Certificate"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "How a Student Changes Their Church Account Name.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-a-Student-Changes-Their-Church-Account-Name"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "How Students Update Personal Information in Their Portal.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-Students-Update-Personal-Information-in-Their-Portal"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "Improving Your Shepherding.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Improving-Your-Shepherding"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "Keep the Spirit in the Gathering.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Keep-the-Spirit-in-the-Gathering"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "Looking Out For The Hidden Crisis.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Looking-Out-For-The-Hidden-Crisis"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "Missionary Student in Crisis Escalation Policy.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Missionary-Student-in-Crisis-Escalation-Policy"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "New Student New Missionary.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/New-Student-New-Missionary"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "New Student Visit Instructions.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/New-Student-Visit-Instructions"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "Providing Christlike Feedback.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Providing-Christlike-Feedback"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "Resources for New and Continuing Students.png",
#     "https://missionaries.prod.byu-pathway.psdops.com/Resources-for-New-and-Continuing-Students.png"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "SHEP - Building a Community of Friendship.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/SHEP-Building-a-Community-of-Friendship"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "SHEP - Lending Money to Students.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/SHEP-Lending-Money-to-Students"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "Shepherd with Charity.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Shepherd-with-Charity"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "Student Issue Escalate Process.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/student-issues-escalate-process"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "Support Options for Students.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/SupportOptionsforStudents"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "Support Students with Disabilities.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Support-Students-with-Disabilities"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "The 3 P's Purpose, Power, & Plan.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/The-3-P's-Purpose,-Power,-&-Plan"
#   ],
#   [
#     "Shepherding / Ministering",
#     null,
#     "Using BYUPW Support Knowledge Articles.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Using-BYUPW-Support-Knowledge-Articles"
#   ],
#   [
#     "Student/Learner Portal",
#     null,
#     "Learning Platform Walkthrough",
#     "https://missionaries.prod.byu-pathway.psdops.com/Learning-Platform-Walkthrough"
#   ],
#   [
#     "Student Software & Uses",
#     "Student Helps, Needs & Information",
#     "Delayed Access to Microsoft Office Suite Download.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Delayed-Access-to-Microsoft-Office-Suite-Download"
#   ],
#   [
#     "Student Software & Uses",
#     "Student Helps, Needs & Information",
#     "Hardware and Software in PC 101, 102, and 103.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Hardware-and-Software-in-PC-101,-102,-and-103"
#   ],
#   [
#     "Webinars and Special Training",
#     null,
#     "Flier Webinar US Canada Missionaries Fall 2021.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Flier-Webinar-US-Canada-Missionaries-Fall-2021"
#   ],
#   [
#     "Webinars and Special Training",
#     null,
#     "Webinar Domesitic August 8 (English).pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Webinar-Domesitic-August-8-(English)"
#   ],
#   [
#     "Webinars and Special Training",
#     null,
#     "Webinar Domestic Agosto 8 (Spanish).pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Webinar-Domestic-Agosto-8-(Spanish)"
#   ],
#   [
#     "Webinars and Special Training",
#     null,
#     "Webinar Domestic August 15 (YSA).pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Webinar-Domestic-August-15-(YSA)"
#   ],
#   [
#     "Webinars and Special Training",
#     null,
#     "Webinar Domestic August 22 (English).pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Webinar-Domestic-August-22-(English)"
#   ],
#   [
#     "WhatsApp",
#     null,
#     "Downloading WhatsApp to a Computer.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Downloading-WhatsApp-to-a-Computer"
#   ],
#   [
#     "Zoom",
#     "Zoom Accounts for Missionaries",
#     "Activate Your New Zoom Account.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Activate-Your-New-Zoom-Account"
#   ],
#   [
#     "Zoom",
#     "Zoom Accounts for Missionaries",
#     "Download and Install Zoom for Mac.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Download-and-Install-Zoom-for-Mac"
#   ],
#   [
#     "Zoom",
#     "Zoom Accounts for Missionaries",
#     "Download and Install Zoom for PC.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Download-and-Install-Zoom-for-PC"
#   ],
#   [
#     "Zoom",
#     "Zoom Accounts for Missionaries",
#     "Mac Zoom Installation.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Mac-Zoom-Installation"
#   ],
#   [
#     "Zoom",
#     "Zoom Accounts for Missionaries",
#     "Merge Your Zoom Account.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Merge-Your-Zoom-Account"
#   ],
#   [
#     "Zoom",
#     "How Missionaries are to Use Zoom",
#     "Log in to the Zoom Website.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Log-in-to-the-Zoom-Website"
#   ],
#   [
#     "Zoom",
#     "How Missionaries are to Use Zoom",
#     "Opening Your Zoom Room.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Opening-Your-Zoom-Room"
#   ],
#   [
#     "Zoom",
#     "Zoom Policies and Usage for Missionaries",
#     "Using Your Zoom Room During the Week.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Using-Your-Zoom-Room-During-the-Week"
#   ],
#   [
#     "Zoom",
#     "Zoom and Devices",
#     "Tips for Zoom on a Mobile App.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Tips-for-Zoom-on-a-Mobile-App"
#   ],
#   [
#     "Zoom",
#     "Breakout Rooms",
#     "Breakout Room Basics.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Breakout-Room-Basics"
#   ],
#   [
#     "Zoom",
#     "Breakout Rooms",
#     "Breakout Rooms - Manual Creation.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Breakout-Room-Manual-Creation"
#   ],
#   [
#     "Zoom",
#     "Breakout Rooms",
#     "Communicate to All Breakout Rooms.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Communicate-to-All-Breakout-Rooms"
#   ],
#   [
#     "Zoom",
#     "Share Screen",
#     "Share Audio and Video.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Share-Audio-and-Video"
#   ],
#   [
#     "Zoom",
#     "Share Screen",
#     "Share Multiple Screens.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Share-Multiple-Screens"
#   ],
#   [
#     "Zoom",
#     "Share Screen",
#     "Share Screen to All Breakout Rooms.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Share-Screen-to-All-Breakout-Rooms"
#   ],
#   [
#     "Zoom",
#     "Share Screen",
#     "Share Your Screen in Zoom.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Share-Your-Screen-in-Zoom"
#   ],
#   [
#     "Zoom",
#     "Host",
#     "Claim Host When Substituting.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Claim-Host-When-Substituting"
#   ],
#   [
#     "Zoom",
#     "Host",
#     "Assigning a Host During a Gathering.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Assigning-a-Host-During-a-Gathering"
#   ],
#   [
#     "Zoom",
#     "Host Key",
#     "Finding or Updating Your Host Key.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Finding-or-Updating-Your-Host-Key"
#   ],
#   [
#     "Zoom",
#     "Co-Host",
#     "Assigning a Cohost.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Assigning-a-Cohost"
#   ],
#   [
#     "Zoom",
#     "Chat",
#     "Chat.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Chat"
#   ],
#   [
#     "Zoom",
#     "Update Zoom Software",
#     "Checking for Updates.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Checking-for-Updates"
#   ],
#   [
#     "Zoom",
#     "Update Zoom Software",
#     "Updating Your Profile Settings.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Updating-Your-Profile-Settings"
#   ],
#   [
#     "Zoom",
#     "Update Zoom Software",
#     "Updating Your Zoom Room Passcode.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Updating-Your-Zoom-Room-Passcode"
#   ],
#   [
#     "Zoom",
#     "Joining a Zoom Meeting",
#     "How Students Access Your Zoom Room.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-Students-Access-Your-Zoom-Room"
#   ],
#   [
#     "Zoom",
#     "Joining a Zoom Meeting",
#     "Joining A Zoom Meeting.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Joining-A-Zoom-Meeting"
#   ],
#   [
#     "Zoom",
#     "Joining a Zoom Meeting",
#     "Zoom Find and Share Your Zoom Room Link.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Zoom-Find-and-Share-Link"
#   ],
#   [
#     "Zoom",
#     "Zoom Room Views",
#     "Gallery and Speaker View.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Gallery-and-Speaker-View"
#   ],
#   [
#     "Zoom",
#     "Zoom Features",
#     "How to Show Participant Names.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/How-to-Show-Participant-Names"
#   ],
#   [
#     "Zoom",
#     "Zoom Features",
#     "Learn the Basic Features of Zoom.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Learn-the-Basic-Features-of-Zoom"
#   ],
#   [
#     "Zoom",
#     "Zoom Features",
#     "Zoom-Feature-Overview.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Zoom-Feature-Overview"
#   ],
#   [
#     "Zoom",
#     "Whiteboards",
#     "Sharing a Whiteboard.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Sharing-a-Whiteboard"
#   ],
#   [
#     "Zoom",
#     "Whiteboards",
#     "Zoom Online Whiteboards.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Zoom-Online-Whiteboards"
#   ],
#   [
#     "Zoom",
#     "Record",
#     "Policy - Zoom Recordings.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Policy-Zoom-Recordings"
#   ],
#   [
#     "Zoom",
#     "Security",
#     "Security.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Security"
#   ],
#   [
#     "Zoom",
#     "Video Settings",
#     "Video Settings.pdf",
#     "https://missionaries.prod.byu-pathway.psdops.com/Video-Settings"
#   ]
# ]

# %% [markdown]
# Now we will save our data into the `missionary.csv` file.

# %%
with open("missionary.csv", "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(data2)
