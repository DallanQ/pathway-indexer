# %% [markdown]
# #### Index

# %%
import os
import pandas as pd
import requests
from playwright.async_api import async_playwright
import zlib
from pathway_indexer.parser import parse_files_to_md
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/isaiaszc/pathway/pathway-
# [nltk_data]     indexer/.venv/lib/python3.12/site-
# [nltk_data]     packages/llama_index/core/_static/nltk_cache...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=False)
page = await browser.new_page()

# %%
def generate_hash_filename(url):
    """Generate a hash of the URL to use as a filename."""
    url_hash = zlib.crc32(url.encode())
    file_name = f"{url_hash:x}"
    return file_name

# %%
save_path = "../../data/data_30_10"
url = "https://help.byupathway.edu/knowledgebase/"

# %%
# in the save_path create 2 folders, crawl and out. inside the out folder create a folder called from_html
os.makedirs(f"{save_path}/crawl", exist_ok=True)
os.makedirs(f"{save_path}/out", exist_ok=True)
os.makedirs(f"{save_path}/out/from_html", exist_ok=True)

# %%
await page.goto(url)
await page.wait_for_load_state()

# %%
while True:
    try:
        await page.click("text=Show More...")
        button = page.query_selector("#pagingButton")
    except:
        break
# Out:
# /tmp/ipykernel_12720/1682996073.py:4: RuntimeWarning: coroutine 'Page.query_selector' was never awaited
#   button = page.query_selector("#pagingButton")
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
# get the element with id articleList
articles = await page.query_selector("#articleList")
# get all the links inside it, the link is the a tag, the title in the h5 tag inside the a tag and the descripcion in the p tag inside the a tag
links = await articles.query_selector_all("a")
data = []
for link in links:
    title = await link.query_selector("h5")
    description = await link.query_selector("p")
    filename = generate_hash_filename(url + await link.get_attribute("href"))
    data.append(
        {
            "URL": url + await link.get_attribute("href"),
            "Section": await title.inner_text(),
            "Subsection": await description.inner_text(),
            "Title": await title.inner_text(),
            "filename": filename,
        }
    )

df = pd.DataFrame(data)
df
# Out:
#                                                    URL  \
# 0    https://help.byupathway.edu/knowledgebase/arti...
# 1    https://help.byupathway.edu/knowledgebase/arti...
# 2    https://help.byupathway.edu/knowledgebase/arti...
# 3    https://help.byupathway.edu/knowledgebase/arti...
# 4    https://help.byupathway.edu/knowledgebase/arti...
# ..                                                 ...
# 125  https://help.byupathway.edu/knowledgebase/arti...
# 126  https://help.byupathway.edu/knowledgebase/arti...
# 127  https://help.byupathway.edu/knowledgebase/arti...
# 128  https://help.byupathway.edu/knowledgebase/arti...
# 129  https://help.byupathway.edu/knowledgebase/arti...
#
#                                                Section  \
# 0              How long does it take to get a decision
# 1    Academic Misconduct Policies for PathwayConnec...
# 2                             PC - Disruptive Behavior
# 3                Institute/Religion Course Information
# 4                          Autodrop for EnglishConnect
# ..                                                 ...
# 125                             Admission Requirements
# 126                        Submitting Transfer Credits
# 127                        Inviting Friends to Pathway
# 128                              Viewing Account Holds
# 129                     Applying for Tuition Discounts
#
#                                             Subsection  \
# 0    How long will it take to get my admission deci...
# 1    What are the policies for academic misconduct ...
# 2                                                    .
# 3    What are the requirements for transferring Ins...
# 4                 What is Autodrop for EnglishConnect?
# ..                                                 ...
# 125  Is there anything that could stop me from join...
# 126       Where do I go to submit my transfer credits?
# 127  What are some ways I can encourage someone I k...
# 128             How do I view the holds on my account?
# 129          Where can I apply for a tuition discount?
#
#                                                  Title  filename
# 0              How long does it take to get a decision  200631eb
# 1    Academic Misconduct Policies for PathwayConnec...  69b665df
# 2                             PC - Disruptive Behavior  c08db428
# 3                Institute/Religion Course Information  e49f35bd
# 4                          Autodrop for EnglishConnect  e55d5f8a
# ..                                                 ...       ...
# 125                             Admission Requirements  2b532722
# 126                        Submitting Transfer Credits  c49f2c39
# 127                        Inviting Friends to Pathway  ba2e5084
# 128                              Viewing Account Holds  34e7b84d
# 129                     Applying for Tuition Discounts  c3f2e820
#
# [130 rows x 5 columns]

# %% [markdown]
# #### Crawler

# %%
# save the df in a csv file
df.to_csv(f"{save_path}/articles.csv", index=False)
df.to_csv(f"{save_path}/all_links.csv", index=False)  # temporary

# %%
for index, row in df.iterrows():
    await page.goto(row["URL"])
    await page.wait_for_load_state()
    content = await page.query_selector(".wrapper-body")
    post_content = await content.inner_html()
    if post_content:
        with open(f"{save_path}/crawl/{row["filename"]}.html", "w") as f:
            f.write(post_content)

# %%
await browser.close()

# %% [markdown]
# #### Parser

# %%
exclude_path = "../../data/data_30_10/excluded_domains.txt"

parse_files_to_md(
    input_directory="../../data/data_30_10/crawl/",
    out_folder="../../data/data_30_10/out/",
    metadata_csv="../articles.csv",
    excluded_domains_path=exclude_path,
)
# Out:
# Starting file processing...
# Processing file: ../../data/data_30_10/crawl/5a645d39.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/5a645d39.txt
# Started parsing the file under job_id 469dd1e7-6fa0-45dd-92c0-4e45e2baf771
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/5a645d39.md
# Processing file: ../../data/data_30_10/crawl/123fa75.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/123fa75.txt
# Started parsing the file under job_id 4b4bc1e5-42f5-4e01-8255-6fdc4342ccd6
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/123fa75.md
# Processing file: ../../data/data_30_10/crawl/c36d0c83.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/c36d0c83.txt
# Started parsing the file under job_id a0b657c8-6306-4d2e-a96a-0aeeef8eeb5f
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/c36d0c83.md
# Processing file: ../../data/data_30_10/crawl/7b39ca29.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/7b39ca29.txt
# Started parsing the file under job_id 79aa27e9-358e-46d4-aaa5-1103f9d0d1bb
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/7b39ca29.md
# Processing file: ../../data/data_30_10/crawl/1f2d53a3.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/1f2d53a3.txt
# Started parsing the file under job_id d3009af5-4431-4827-a8fe-fe5af070706b
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/1f2d53a3.md
# Processing file: ../../data/data_30_10/crawl/c4789414.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/c4789414.txt
# Started parsing the file under job_id 948c2a09-0c92-4f3b-b716-a9c660ce5e0c
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/c4789414.md
# Processing file: ../../data/data_30_10/crawl/aa1cc94d.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/aa1cc94d.txt
# Started parsing the file under job_id 848966c5-cf54-4ac6-9094-35e1b5f9f7a8
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/aa1cc94d.md
# Processing file: ../../data/data_30_10/crawl/c3efabf.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/c3efabf.txt
# Started parsing the file under job_id 19173f42-670e-4731-ab6c-06a6d018b768
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/c3efabf.md
# Processing file: ../../data/data_30_10/crawl/24ad7d0a.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/24ad7d0a.txt
# Started parsing the file under job_id fd0aa45b-ed15-496c-8ecf-177a63aac6a8
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/24ad7d0a.md
# Processing file: ../../data/data_30_10/crawl/cd296012.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/cd296012.txt
# Started parsing the file under job_id b9b4872c-d223-4534-8f76-35f57861ce30
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/cd296012.md
# Processing file: ../../data/data_30_10/crawl/fdfc5872.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/fdfc5872.txt
# Started parsing the file under job_id 87f905d9-cbfc-446d-942d-47e924cad222
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/fdfc5872.md
# Processing file: ../../data/data_30_10/crawl/13ee0915.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/13ee0915.txt
# Started parsing the file under job_id 086bcc3d-9011-438f-aecf-4e1ec71e3fe9
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/13ee0915.md
# Processing file: ../../data/data_30_10/crawl/169b1f88.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/169b1f88.txt
# Started parsing the file under job_id d12ebb82-8601-46e5-83ad-8d9e5b91d6cc
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/169b1f88.md
# Processing file: ../../data/data_30_10/crawl/f0e158b8.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/f0e158b8.txt
# Started parsing the file under job_id 8e0399a5-03dd-49fc-bd01-7412533a4de0
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/f0e158b8.md
# Processing file: ../../data/data_30_10/crawl/a33561c5.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/a33561c5.txt
# Started parsing the file under job_id 8ff49254-bd3e-4c69-aa83-505f45bb355a
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/a33561c5.md
# Processing file: ../../data/data_30_10/crawl/336dc479.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/336dc479.txt
# Started parsing the file under job_id db8ec8fa-e71d-428b-8907-1961a143a892
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/336dc479.md
# Processing file: ../../data/data_30_10/crawl/2b532722.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/2b532722.txt
# Started parsing the file under job_id ba835a27-a24f-4d9f-8dd5-2e6644914c96
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/2b532722.md
# Processing file: ../../data/data_30_10/crawl/48232b45.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/48232b45.txt
# Started parsing the file under job_id 13168444-6590-4bd0-b599-ce92483faee0
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/48232b45.md
# Processing file: ../../data/data_30_10/crawl/b3981caf.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/b3981caf.txt
# Started parsing the file under job_id e8f6dae0-ba9a-4675-b939-4f0a7cbe6eb9
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/b3981caf.md
# Processing file: ../../data/data_30_10/crawl/32481663.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/32481663.txt
# Started parsing the file under job_id 14dfc01a-87d9-4bc0-9039-145bd8959f6b
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/32481663.md
# Processing file: ../../data/data_30_10/crawl/2a914d15.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/2a914d15.txt
# Started parsing the file under job_id b927e8b9-8768-47a2-bb5b-2815b8f0ff7b
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/2a914d15.md
# Processing file: ../../data/data_30_10/crawl/c2308217.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/c2308217.txt
# Started parsing the file under job_id ab67348a-418d-488a-b311-8597d1d1c412
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/c2308217.md
# Processing file: ../../data/data_30_10/crawl/b537b281.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/b537b281.txt
# Started parsing the file under job_id a3f4af48-1ab5-459e-a986-e3875f723828
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/b537b281.md
# Processing file: ../../data/data_30_10/crawl/865c5e97.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/865c5e97.txt
# Started parsing the file under job_id 7587ab38-dfdf-4b53-b75a-09fcd2ee6f20
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/865c5e97.md
# Processing file: ../../data/data_30_10/crawl/338a7c54.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/338a7c54.txt
# Started parsing the file under job_id 781b6cf9-a24f-48cd-b229-33ef4dce8b20
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/338a7c54.md
# Processing file: ../../data/data_30_10/crawl/9f476fd6.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/9f476fd6.txt
# Started parsing the file under job_id c08bf519-3e5e-41ba-9600-836537dddfb1
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/9f476fd6.md
# Processing file: ../../data/data_30_10/crawl/c315500d.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/c315500d.txt
# Started parsing the file under job_id 72eb8192-cdb0-4f39-9967-63216f8b9e4a
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/c315500d.md
# Processing file: ../../data/data_30_10/crawl/83134812.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/83134812.txt
# Started parsing the file under job_id 791cfe75-4df5-4154-a197-976d5687ba56
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/83134812.md
# Processing file: ../../data/data_30_10/crawl/f64ef696.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/f64ef696.txt
# Started parsing the file under job_id a3252f98-3084-46da-8923-299c15051576
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/f64ef696.md
# Processing file: ../../data/data_30_10/crawl/492998f8.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/492998f8.txt
# Started parsing the file under job_id 659d1e44-574f-401e-995b-bca542c758ab
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/492998f8.md
# Processing file: ../../data/data_30_10/crawl/200631eb.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/200631eb.txt
# Started parsing the file under job_id fe5f7e4e-8bd9-4018-949c-a08cabef4b59
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/200631eb.md
# Processing file: ../../data/data_30_10/crawl/8462bc40.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/8462bc40.txt
# Started parsing the file under job_id e0649550-d7d9-4954-8754-f47fae014a28
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/8462bc40.md
# Processing file: ../../data/data_30_10/crawl/dae9d961.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/dae9d961.txt
# Started parsing the file under job_id 6d404e39-71c4-4b45-99a6-7277bed4dbd9
# .Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/dae9d961.md
# Processing file: ../../data/data_30_10/crawl/984ec70a.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/984ec70a.txt
# Started parsing the file under job_id 2db0d880-9ce7-4a81-b709-2a14c4feaa35
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/984ec70a.md
# Processing file: ../../data/data_30_10/crawl/e49f35bd.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/e49f35bd.txt
# Started parsing the file under job_id 9cf04c6e-5ec7-45cd-ad6f-2252c3418fb5
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/e49f35bd.md
# Processing file: ../../data/data_30_10/crawl/446af4ef.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/446af4ef.txt
# Started parsing the file under job_id 75ab8547-f27a-4afe-8e75-e8e2306a178a
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/446af4ef.md
# Processing file: ../../data/data_30_10/crawl/5a1c01b7.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/5a1c01b7.txt
# Started parsing the file under job_id ac73ea50-8ac3-4e98-a977-4fc3eb810d66
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/5a1c01b7.md
# Processing file: ../../data/data_30_10/crawl/231d0126.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/231d0126.txt
# Started parsing the file under job_id 123d71ce-6ed7-40f3-88da-71554d937284
# ..Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/231d0126.md
# Processing file: ../../data/data_30_10/crawl/2d636daf.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/2d636daf.txt
# Started parsing the file under job_id 13c98554-ae3d-4e49-9c01-1594dc72b812
# .Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/2d636daf.md
# Processing file: ../../data/data_30_10/crawl/13648c09.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/13648c09.txt
# Started parsing the file under job_id 5e186158-7ff1-4a66-b779-f9a7a9b09b10
# .Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/13648c09.md
# Processing file: ../../data/data_30_10/crawl/716f3ea9.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/716f3ea9.txt
# Started parsing the file under job_id c6a7d05b-9821-4bbf-9485-feb59ec44de1
# ..Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/716f3ea9.md
# Processing file: ../../data/data_30_10/crawl/7f9286c8.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/7f9286c8.txt
# Started parsing the file under job_id 92ac3d1c-c81c-4dcf-b242-b39679da58f8
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/7f9286c8.md
# Processing file: ../../data/data_30_10/crawl/1bfe43cc.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/1bfe43cc.txt
# Started parsing the file under job_id fd46af78-d1b1-4c3b-9079-8441eafb71cc
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/1bfe43cc.md
# Processing file: ../../data/data_30_10/crawl/dc46774f.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/dc46774f.txt
# Started parsing the file under job_id 5055843d-a7ae-4d8d-8068-ad5790629fa7
# ..Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/dc46774f.md
# Processing file: ../../data/data_30_10/crawl/c08db428.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/c08db428.txt
# Started parsing the file under job_id ef2b1772-3b0a-4a9e-af30-02a1330a7ee8
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/c08db428.md
# Processing file: ../../data/data_30_10/crawl/fb2baad2.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/fb2baad2.txt
# Started parsing the file under job_id 4aa5100d-a636-4d6f-b321-a0dcdac42ad1
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/fb2baad2.md
# Processing file: ../../data/data_30_10/crawl/982aabcf.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/982aabcf.txt
# Started parsing the file under job_id 962ae571-a54d-46a3-ba4d-aae704b177cb
# .Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/982aabcf.md
# Processing file: ../../data/data_30_10/crawl/12480fe7.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/12480fe7.txt
# Started parsing the file under job_id 12793f3a-9a0b-4519-aca5-0b56a6abea09
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/12480fe7.md
# Processing file: ../../data/data_30_10/crawl/26367b66.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/26367b66.txt
# Started parsing the file under job_id ec6be100-adeb-4de2-afb6-bd3e17cd662b
# .Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/26367b66.md
# Processing file: ../../data/data_30_10/crawl/ffde8aee.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/ffde8aee.txt
# Error while parsing the file '<bytes/buffer>':
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/ffde8aee.md
# Error parsing TXT file to MD. Retrying...
# Started parsing the file under job_id b4d9e7aa-a9b8-4730-a2e7-9906995b305f
# ...Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/ffde8aee.md
# Processing file: ../../data/data_30_10/crawl/f15b6e01.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/f15b6e01.txt
# Started parsing the file under job_id 5e235ae2-7ee6-4766-9113-5bae6095cf0f
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/f15b6e01.md
# Processing file: ../../data/data_30_10/crawl/13f2395e.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/13f2395e.txt
# Started parsing the file under job_id b9610ff5-04c6-4057-816e-90c1a7c7bc70
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/13f2395e.md
# Processing file: ../../data/data_30_10/crawl/c3f2e820.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/c3f2e820.txt
# Started parsing the file under job_id 1da79f1b-43c8-4210-983a-50b33857cdab
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/c3f2e820.md
# Processing file: ../../data/data_30_10/crawl/409fd4d3.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/409fd4d3.txt
# Started parsing the file under job_id c8f9df5a-98f1-43dc-890f-944ce16472b7
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/409fd4d3.md
# Processing file: ../../data/data_30_10/crawl/7df208c2.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/7df208c2.txt
# Started parsing the file under job_id f45a6d8a-0ba4-4831-8a2f-b88bba46dcc6
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/7df208c2.md
# Processing file: ../../data/data_30_10/crawl/239ed5ce.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/239ed5ce.txt
# Started parsing the file under job_id b49d4908-5dd3-41db-a63a-56e5ea95f759
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/239ed5ce.md
# Processing file: ../../data/data_30_10/crawl/708b64cd.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/708b64cd.txt
# Started parsing the file under job_id 82be40c5-447f-479c-b6e0-619d3aed639f
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/708b64cd.md
# Processing file: ../../data/data_30_10/crawl/e8405f40.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/e8405f40.txt
# Started parsing the file under job_id 6108d767-8046-469d-bf66-c6064defa7c0
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/e8405f40.md
# Processing file: ../../data/data_30_10/crawl/2dfc890c.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/2dfc890c.txt
# Started parsing the file under job_id 333da5d8-94ba-4ea6-85e8-a5cdce9270af
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/2dfc890c.md
# Processing file: ../../data/data_30_10/crawl/6f47a72c.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/6f47a72c.txt
# Started parsing the file under job_id 826dfcdd-3faf-49df-83b3-67ad7cd05ed7
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/6f47a72c.md
# Processing file: ../../data/data_30_10/crawl/c55d460e.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/c55d460e.txt
# Started parsing the file under job_id 868ee247-a9c6-4225-bc96-9349c3e9be50
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/c55d460e.md
# Processing file: ../../data/data_30_10/crawl/8b415e5d.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/8b415e5d.txt
# Started parsing the file under job_id 23180c16-8169-4920-bdc6-8d4b0da3e071
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/8b415e5d.md
# Processing file: ../../data/data_30_10/crawl/dd63a555.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/dd63a555.txt
# Started parsing the file under job_id f0f8970e-621a-49e4-a633-46f43ff8843d
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/dd63a555.md
# Processing file: ../../data/data_30_10/crawl/e4fb5978.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/e4fb5978.txt
# Started parsing the file under job_id 4bcb00e6-c05e-4274-bda7-7e38a89b5b93
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/e4fb5978.md
# Processing file: ../../data/data_30_10/crawl/6f3ffba2.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/6f3ffba2.txt
# Started parsing the file under job_id 7d30f72e-522e-4cff-acf7-41401ff81d75
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/6f3ffba2.md
# Processing file: ../../data/data_30_10/crawl/a7e671aa.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/a7e671aa.txt
# Started parsing the file under job_id de84c68b-a735-49a7-a0a4-87d905e99ff7
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/a7e671aa.md
# Processing file: ../../data/data_30_10/crawl/ef2d9b59.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/ef2d9b59.txt
# Started parsing the file under job_id 4e0f032c-4037-4d1b-9c1c-a34debb62ecb
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/ef2d9b59.md
# Processing file: ../../data/data_30_10/crawl/201a01a0.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/201a01a0.txt
# Started parsing the file under job_id d236f23a-0d8b-4998-9796-425a98722912
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/201a01a0.md
# Processing file: ../../data/data_30_10/crawl/ef55c7d7.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/ef55c7d7.txt
# Started parsing the file under job_id 50ca5f0a-91a8-48b9-b469-77fc0a67ee46
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/ef55c7d7.md
# Processing file: ../../data/data_30_10/crawl/46f8a377.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/46f8a377.txt
# Started parsing the file under job_id 637913f7-4867-4538-98ed-94daeab92b2f
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/46f8a377.md
# Processing file: ../../data/data_30_10/crawl/2ec18992.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/2ec18992.txt
# Started parsing the file under job_id 21ee8fc4-fcd1-4cea-813f-bad4ff076471
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/2ec18992.md
# Processing file: ../../data/data_30_10/crawl/2a76f538.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/2a76f538.txt
# Started parsing the file under job_id db5ca232-9054-41bf-a3a8-93a0902deeb2
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/2a76f538.md
# Processing file: ../../data/data_30_10/crawl/64f509c8.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/64f509c8.txt
# Started parsing the file under job_id f126f657-6e69-4a8e-8eb6-b16c72f83647
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/64f509c8.md
# Processing file: ../../data/data_30_10/crawl/2e83d504.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/2e83d504.txt
# Started parsing the file under job_id 4ad7c0a8-4da8-4d57-a2ca-8c12efd8b8f2
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/2e83d504.md
# Processing file: ../../data/data_30_10/crawl/51381a04.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/51381a04.txt
# Started parsing the file under job_id 0b4f0ed3-449a-48d7-8360-59c5b9b2205e
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/51381a04.md
# Processing file: ../../data/data_30_10/crawl/31ff93e1.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/31ff93e1.txt
# Started parsing the file under job_id a55ae8e2-b250-4d09-97e8-acc132d1e958
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/31ff93e1.md
# Processing file: ../../data/data_30_10/crawl/3aa3d4dc.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/3aa3d4dc.txt
# Started parsing the file under job_id cdb426f6-39c0-4410-975a-d5a67901231c
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/3aa3d4dc.md
# Processing file: ../../data/data_30_10/crawl/2d1b3121.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/2d1b3121.txt
# Started parsing the file under job_id 39f80235-4a3d-4f9d-944e-bc06bb4ff11f
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/2d1b3121.md
# Processing file: ../../data/data_30_10/crawl/ad0951da.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/ad0951da.txt
# Started parsing the file under job_id 6d423de8-6239-4966-a3cf-c5c03ea05558
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/ad0951da.md
# Processing file: ../../data/data_30_10/crawl/b4f5d8b6.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/b4f5d8b6.txt
# Started parsing the file under job_id 4ef1d832-3013-478f-9881-3112b46203a5
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/b4f5d8b6.md
# Processing file: ../../data/data_30_10/crawl/a2f70bf2.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/a2f70bf2.txt
# Started parsing the file under job_id f65389b9-36b0-44da-b9a9-1fb8be3b4499
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/a2f70bf2.md
# Processing file: ../../data/data_30_10/crawl/5afbb99a.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/5afbb99a.txt
# Started parsing the file under job_id 018dce2b-5ea6-4f4a-aa3a-d7e72c2c02dd
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/5afbb99a.md
# Processing file: ../../data/data_30_10/crawl/d5f03b64.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/d5f03b64.txt
# Started parsing the file under job_id 69aa1cbc-05f9-4f28-8738-214b93bf9de8
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/d5f03b64.md
# Processing file: ../../data/data_30_10/crawl/aa6495c3.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/aa6495c3.txt
# Started parsing the file under job_id c979d0d7-1f5d-4db3-bf16-b8146521efdb
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/aa6495c3.md
# Processing file: ../../data/data_30_10/crawl/bd1df840.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/bd1df840.txt
# Started parsing the file under job_id ba8ee7a2-059d-4017-b2cc-733fd4377de5
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/bd1df840.md
# Processing file: ../../data/data_30_10/crawl/5d967d83.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/5d967d83.txt
# Started parsing the file under job_id 340a85ab-cbfa-4bf8-8061-4c1fa84b5d87
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/5d967d83.md
# Processing file: ../../data/data_30_10/crawl/3f241bd3.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/3f241bd3.txt
# Started parsing the file under job_id 102e954f-cb86-461c-8179-92b73925657a
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/3f241bd3.md
# Processing file: ../../data/data_30_10/crawl/e55d5f8a.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/e55d5f8a.txt
# Started parsing the file under job_id 8fa05246-a551-4ef3-8ef9-a22b57ca98ae
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/e55d5f8a.md
# Processing file: ../../data/data_30_10/crawl/de9f2db5.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/de9f2db5.txt
# Started parsing the file under job_id 2ad9daf6-0d6e-4a46-a1b8-9b950cf9ba52
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/de9f2db5.md
# Processing file: ../../data/data_30_10/crawl/4412a861.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/4412a861.txt
# Started parsing the file under job_id 79360858-dbc8-4583-8e3a-e57bfc10cff2
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/4412a861.md
# Processing file: ../../data/data_30_10/crawl/c49f2c39.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/c49f2c39.txt
# Started parsing the file under job_id 2bd99bbd-cda3-4635-af55-2a7d63adf5c4
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/c49f2c39.md
# Processing file: ../../data/data_30_10/crawl/ba2e5084.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/ba2e5084.txt
# Started parsing the file under job_id 807eb62b-ae83-4a7c-8396-4f2e77501fa7
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/ba2e5084.md
# Processing file: ../../data/data_30_10/crawl/619c2f1e.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/619c2f1e.txt
# Started parsing the file under job_id 99591405-a6fe-4a02-8126-e7d15c4dbf2a
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/619c2f1e.md
# Processing file: ../../data/data_30_10/crawl/b37fa482.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/b37fa482.txt
# Started parsing the file under job_id 7792ca1f-2be2-4fdc-a663-7a46d12be97c
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/b37fa482.md
# Processing file: ../../data/data_30_10/crawl/ef49f79c.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/ef49f79c.txt
# Started parsing the file under job_id 8460f453-37ab-426f-8d34-01117ae9afeb
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/ef49f79c.md
# Processing file: ../../data/data_30_10/crawl/be7e9403.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/be7e9403.txt
# Started parsing the file under job_id 378a2424-a77b-4e2f-875b-c8b7f250e1a9
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/be7e9403.md
# Processing file: ../../data/data_30_10/crawl/43e088db.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/43e088db.txt
# Started parsing the file under job_id beb2365c-f0ab-43e2-954e-6a0c3fe0ba4c
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/43e088db.md
# Processing file: ../../data/data_30_10/crawl/f123328f.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/f123328f.txt
# Started parsing the file under job_id 99f30f02-7754-4db6-a6d7-fedc2c40635a
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/f123328f.md
# Processing file: ../../data/data_30_10/crawl/448d4cc2.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/448d4cc2.txt
# Started parsing the file under job_id 085724d0-a85c-4d04-a023-d1c3d44c0637
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/448d4cc2.md
# Processing file: ../../data/data_30_10/crawl/cceb0a25.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/cceb0a25.txt
# Started parsing the file under job_id e2b77756-5014-4a4b-a580-0e3a6135dc67
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/cceb0a25.md
# Processing file: ../../data/data_30_10/crawl/4da4e44a.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/4da4e44a.txt
# Started parsing the file under job_id 3f54d04f-9058-4d56-a415-2c2b8d973d15
# ....Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/4da4e44a.md
# Processing file: ../../data/data_30_10/crawl/213fd3ba.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/213fd3ba.txt
# Started parsing the file under job_id 37e31def-d10c-4c0f-b3da-054d43d28fd4
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/213fd3ba.md
# Processing file: ../../data/data_30_10/crawl/7624cae3.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/7624cae3.txt
# Started parsing the file under job_id 409ef2a9-a238-499f-a039-c4ce3001fae0
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/7624cae3.md
# Processing file: ../../data/data_30_10/crawl/4e060077.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/4e060077.txt
# Started parsing the file under job_id 4476c589-c572-4967-98c1-2be3d0306d3a
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/4e060077.md
# Processing file: ../../data/data_30_10/crawl/b0832c62.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/b0832c62.txt
# Started parsing the file under job_id 76d48d48-5915-4dbc-87ce-ec7937ca6ea5
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/b0832c62.md
# Processing file: ../../data/data_30_10/crawl/c979a495.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/c979a495.txt
# Started parsing the file under job_id b0fd9651-9018-4480-8bed-40daa7af1f29
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/c979a495.md
# Processing file: ../../data/data_30_10/crawl/a54777de.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/a54777de.txt
# Started parsing the file under job_id 447da6fe-3f8e-426c-9d32-8281cbcf20ce
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/a54777de.md
# Processing file: ../../data/data_30_10/crawl/654f3f71.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/654f3f71.txt
# Started parsing the file under job_id 8ebaf64f-c4d3-4a98-b950-d29a5f70ba91
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/654f3f71.md
# Processing file: ../../data/data_30_10/crawl/454f26f5.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/454f26f5.txt
# Started parsing the file under job_id 0f386591-f1ec-4348-a5f5-f059829c7881
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/454f26f5.md
# Processing file: ../../data/data_30_10/crawl/1838cb34.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/1838cb34.txt
# Started parsing the file under job_id b5853ff8-a6e5-4b0f-99dc-e82b957c0548
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/1838cb34.md
# Processing file: ../../data/data_30_10/crawl/aa832dee.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/aa832dee.txt
# Started parsing the file under job_id 21075042-5c5e-43eb-8abe-efefb2114d99
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/aa832dee.md
# Processing file: ../../data/data_30_10/crawl/a7799509.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/a7799509.txt
# Started parsing the file under job_id d1c4c101-b373-4194-81d0-b4c4e7973377
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/a7799509.md
# Processing file: ../../data/data_30_10/crawl/34e7b84d.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/34e7b84d.txt
# Started parsing the file under job_id e43a5b52-e057-4391-ab27-d8fee1f3b353
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/34e7b84d.md
# Processing file: ../../data/data_30_10/crawl/122c6322.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/122c6322.txt
# Started parsing the file under job_id 57efb754-c628-41f5-b71b-2363ba03d5cf
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/122c6322.md
# Processing file: ../../data/data_30_10/crawl/6dd5f0b4.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/6dd5f0b4.txt
# Started parsing the file under job_id 8f970a55-27ee-412e-a4c6-0f0775e1af5f
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/6dd5f0b4.md
# Processing file: ../../data/data_30_10/crawl/b868eedd.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/b868eedd.txt
# Started parsing the file under job_id 8fb1cc9c-aec3-407d-b277-a533452d526c
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/b868eedd.md
# Processing file: ../../data/data_30_10/crawl/8afb68e4.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/8afb68e4.txt
# Started parsing the file under job_id daca501f-655a-412f-ba78-9bd584071110
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/8afb68e4.md
# Processing file: ../../data/data_30_10/crawl/1d77ddb1.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/1d77ddb1.txt
# Started parsing the file under job_id 1a1b1851-6564-4cd0-80b2-c9b4706b0df4
# .........Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/1d77ddb1.md
# Processing file: ../../data/data_30_10/crawl/69b665df.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/69b665df.txt
# Started parsing the file under job_id 65b9a3e4-8e91-497f-bd9a-8738c33583fe
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/69b665df.md
# Processing file: ../../data/data_30_10/crawl/8fa84e2a.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/8fa84e2a.txt
# Started parsing the file under job_id 5385d3ea-345d-4c0c-8241-3572a13db8c6
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/8fa84e2a.md
# Processing file: ../../data/data_30_10/crawl/68523fbb.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/68523fbb.txt
# Started parsing the file under job_id 77f3c845-0abb-455f-848c-ee7c94ca287e
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/68523fbb.md
# Processing file: ../../data/data_30_10/crawl/53e8110a.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/53e8110a.txt
# Started parsing the file under job_id 1b3b63bc-79e7-497f-b20f-7e3e448538f8
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/53e8110a.md
# Processing file: ../../data/data_30_10/crawl/895b65e.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/895b65e.txt
# Started parsing the file under job_id 268d9b3f-9a19-4618-956f-6f5df377b934
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/895b65e.md
# Processing file: ../../data/data_30_10/crawl/3f2d4a27.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/3f2d4a27.txt
# Started parsing the file under job_id a2c8d8c4-c4bd-433f-ae11-17600946eab7
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/3f2d4a27.md
# Processing file: ../../data/data_30_10/crawl/2c3ee33b.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/2c3ee33b.txt
# Started parsing the file under job_id acd8bc97-b3db-445b-9d6f-1aad880145e2
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/2c3ee33b.md
# Processing file: ../../data/data_30_10/crawl/c8314bbe.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/c8314bbe.txt
# Started parsing the file under job_id 417b40bb-29df-43c3-8515-75145b0b1279
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/c8314bbe.md
# Processing file: ../../data/data_30_10/crawl/cd90b4e2.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/cd90b4e2.txt
# Started parsing the file under job_id 19daf268-b7d7-4994-8a82-93a06605136d
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/cd90b4e2.md
# Processing file: ../../data/data_30_10/crawl/174545f4.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/174545f4.txt
# Started parsing the file under job_id ff7ae48b-d834-478c-9299-06613f8d9635
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/174545f4.md
# Processing file: ../../data/data_30_10/crawl/60427562.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/60427562.txt
# Started parsing the file under job_id 0f00eddc-fae9-4626-8d44-3f50eb6a2a96
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/60427562.md
# Processing file: ../../data/data_30_10/crawl/6cf9735a.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/6cf9735a.txt
# Started parsing the file under job_id f697299d-ebcd-4320-84d1-71445a0866b0
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/6cf9735a.md
# Processing file: ../../data/data_30_10/crawl/1f550f2d.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/1f550f2d.txt
# Started parsing the file under job_id b69f6f10-e720-4767-9e01-caa4984ffe54
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/1f550f2d.md
# Processing file: ../../data/data_30_10/crawl/8d0019aa.html
# Converted HTML to TXT and saved to: ../../data/data_30_10/out/from_html/8d0019aa.txt
# Started parsing the file under job_id 178774f4-c272-4575-b422-84d035334cdd
# Parsed TXT to MD and saved to: ../../data/data_30_10/out/from_html/8d0019aa.md
# File processing completed.
#
# Associating Markdown files with metadata...
# No metadata found for ../../data/data_30_10/out/from_html/b0832c62.md. Skipping.
# No metadata found for ../../data/data_30_10/out/from_html/53e8110a.md. Skipping.
# Markdown files and their metadata:
# ../../data/data_30_10/out/from_html/ef49f79c.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01302', 'heading': 'Course Registration and Information Guide', 'subheading': '(OLD)', 'title': 'Course Registration and Information Guide'}
# ../../data/data_30_10/out/from_html/a54777de.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01472', 'heading': 'Resolving Financial Holds', 'subheading': 'I have a Financial Hold on my account how can I resolve it?', 'title': 'Resolving Financial Holds'}
# ../../data/data_30_10/out/from_html/be7e9403.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01366', 'heading': 'PC - Tax Information', 'subheading': '.', 'title': 'PC - Tax Information'}
# ../../data/data_30_10/out/from_html/3aa3d4dc.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01728', 'heading': 'OD-DP: 2022 - Applied Technology', 'subheading': 'What is the course sequencing and graduation process for the Applied Technology degree program in 2022?', 'title': 'OD-DP: 2022 - Applied Technology'}
# ../../data/data_30_10/out/from_html/865c5e97.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01713', 'heading': 'OD-DP: 2021 - Applied Technology', 'subheading': 'What is the course sequencing and graduation process for the Applied Technology degree program in 2021?', 'title': 'OD-DP: 2021 - Applied Technology'}
# ../../data/data_30_10/out/from_html/2c3ee33b.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02392', 'heading': 'Offer Acceptance', 'subheading': 'How do I accept my offer?', 'title': 'Offer Acceptance'}
# ../../data/data_30_10/out/from_html/32481663.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02386', 'heading': "Join Gathering's WhatsApp group chat", 'subheading': "How can I join my gathering's WhatsApp group chat?", 'title': "Join Gathering's WhatsApp group chat"}
# ../../data/data_30_10/out/from_html/13648c09.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01814', 'heading': 'OD-DP: 2022 - Applied Business Management', 'subheading': 'What is the course sequencing and graduation process for the Applied Business Management degree program in 2022?', 'title': 'OD-DP: 2022 - Applied Business Management'}
# ../../data/data_30_10/out/from_html/d5f03b64.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02388', 'heading': 'Is completing EnglishConnect3 necessary to move onto the next Program?', 'subheading': 'Do I have to complete EC3 to move onto PathwayConnect?', 'title': 'Is completing EnglishConnect3 necessary to move onto the next Program?'}
# ../../data/data_30_10/out/from_html/f0e158b8.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02357', 'heading': 'Academic Calendar', 'subheading': 'When do courses start for the upcoming term?', 'title': 'Academic Calendar'}
# ../../data/data_30_10/out/from_html/984ec70a.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01303', 'heading': 'Requesting Course Authorization', 'subheading': 'How can BYU-Pathway students request course authorization if they have met pre-requisite requirements?', 'title': 'Requesting Course Authorization'}
# ../../data/data_30_10/out/from_html/b37fa482.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02272', 'heading': 'Selecting Certificates and Degrees', 'subheading': 'How do I choose/change my certificates and degrees?', 'title': 'Selecting Certificates and Degrees'}
# ../../data/data_30_10/out/from_html/ffde8aee.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02406', 'heading': 'General Program Information: Certificates & Degrees', 'subheading': 'Could you tell me more about Certificates & Degrees?', 'title': 'General Program Information: Certificates & Degrees'}
# ../../data/data_30_10/out/from_html/b537b281.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02391', 'heading': 'Student Visa', 'subheading': 'Does BYU-Pathway offer Student Visas to the United States?', 'title': 'Student Visa'}
# ../../data/data_30_10/out/from_html/8d0019aa.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01813', 'heading': 'Registering For Institute', 'subheading': '.', 'title': 'Registering For Institute'}
# ../../data/data_30_10/out/from_html/654f3f71.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01744', 'heading': 'OD-DP: 2023 - Applied Health', 'subheading': 'What is the course sequencing and graduation process for the Applied Health degree program in 2023?', 'title': 'OD-DP: 2023 - Applied Health'}
# ../../data/data_30_10/out/from_html/708b64cd.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01601', 'heading': 'Ensign College Holds', 'subheading': 'How do Ensign College students resolve holds on their accounts, and what are the specific procedures for different types of holds?', 'title': 'Ensign College Holds'}
# ../../data/data_30_10/out/from_html/e4fb5978.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01253', 'heading': 'PC - Late Fee', 'subheading': '.', 'title': 'PC - Late Fee'}
# ../../data/data_30_10/out/from_html/213fd3ba.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01286', 'heading': 'Graduating with Honors', 'subheading': '.', 'title': 'Graduating with Honors'}
# ../../data/data_30_10/out/from_html/ba2e5084.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02299', 'heading': 'Inviting Friends to Pathway', 'subheading': 'What are some ways I can encourage someone I know to enroll at BYU-Pathway?', 'title': 'Inviting Friends to Pathway'}
# ../../data/data_30_10/out/from_html/2dfc890c.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02292', 'heading': 'Clearing Ecclesiastical Endorsement Holds', 'subheading': 'How do I clear an Ecclesiastical Endorsement hold?', 'title': 'Clearing Ecclesiastical Endorsement Holds'}
# ../../data/data_30_10/out/from_html/4e060077.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01370', 'heading': 'PC - Tuition Refunds', 'subheading': '.', 'title': 'PC - Tuition Refunds'}
# ../../data/data_30_10/out/from_html/64f509c8.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02301', 'heading': 'Purchasing BYU-Pathway Merchandise', 'subheading': 'Where can I purchase BYU-Pathway merchandise?', 'title': 'Purchasing BYU-Pathway Merchandise'}
# ../../data/data_30_10/out/from_html/c315500d.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02277', 'heading': 'Accessing Microsoft 365 Apps', 'subheading': 'Where can I access Microsoft 365 Apps?', 'title': 'Accessing Microsoft 365 Apps'}
# ../../data/data_30_10/out/from_html/4412a861.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01725', 'heading': 'OD-DP: 2021 - Professional Studies', 'subheading': 'What is the course sequencing and graduation process for the Professional Studies degree program in 2021?', 'title': 'OD-DP: 2021 - Professional Studies'}
# ../../data/data_30_10/out/from_html/cd296012.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02298', 'heading': 'Requesting Disability Accommodations', 'subheading': 'I have a disability. How can I request accommodation from BYU-Pathway?', 'title': 'Requesting Disability Accommodations'}
# ../../data/data_30_10/out/from_html/336dc479.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02261', 'heading': 'Diagnostic Tests in EnglishConnect 3', 'subheading': 'How are beginning levels for each skill determined in EnglishConnect 3?', 'title': 'Diagnostic Tests in EnglishConnect 3'}
# ../../data/data_30_10/out/from_html/c3f2e820.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02290', 'heading': 'Applying for Tuition Discounts', 'subheading': 'Where can I apply for a tuition discount?', 'title': 'Applying for Tuition Discounts'}
# ...
# ../../data/data_30_10/out/from_html/b3981caf.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02295', 'heading': 'Where to Take an English Language Assessment (ELA)', 'subheading': 'How do I take an English Language Assessment (ELA)?', 'title': 'Where to Take an English Language Assessment (ELA)'}
# ../../data/data_30_10/out/from_html/2d1b3121.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02275', 'heading': 'Changing Your Gathering', 'subheading': 'How and when can I change my gathering?', 'title': 'Changing Your Gathering'}
# ../../data/data_30_10/out/from_html/338a7c54.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02286', 'heading': 'Editing Your Social Security Number (SSN)', 'subheading': 'How do I edit my Social Security Number (SSN)?', 'title': 'Editing Your Social Security Number (SSN)'}
# ../../data/data_30_10/out/from_html/4da4e44a.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01729', 'heading': 'OD-DP: 2022 - Communication (Ensign)', 'subheading': 'What is the course sequencing and graduation process for the Communication degree program in 2022?', 'title': 'OD-DP: 2022 - Communication (Ensign)'}
# ../../data/data_30_10/out/from_html/492998f8.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01129', 'heading': 'Autodrop', 'subheading': 'What is autodrop and how does it work?', 'title': 'Autodrop'}
# ../../data/data_30_10/out/from_html/2d636daf.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01730', 'heading': 'OD-DP: 2022 - Information Technology (Ensign)', 'subheading': 'What is the course sequencing and graduation process for the Information Technology degree program in 2022?', 'title': 'OD-DP: 2022 - Information Technology (Ensign)'}
# ../../data/data_30_10/out/from_html/13ee0915.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01241', 'heading': 'Requesting Grade Changes', 'subheading': '.', 'title': 'Requesting Grade Changes'}
# ../../data/data_30_10/out/from_html/8fa84e2a.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01542', 'heading': 'Navigating and Accessing Courses', 'subheading': '.', 'title': 'Navigating and Accessing Courses'}
# ../../data/data_30_10/out/from_html/68523fbb.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01711', 'heading': 'OD-DP: 2021 - Applied Business Management', 'subheading': 'What is the course sequencing and graduation process for the Applied Business Management degree program in 2021?', 'title': 'OD-DP: 2021 - Applied Business Management'}
# ../../data/data_30_10/out/from_html/1838cb34.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01714', 'heading': 'OD-DP: 2021 - Communication (Ensign)', 'subheading': 'What is the course sequencing and graduation process for the Communication degree program in 2021?', 'title': 'OD-DP: 2021 - Communication (Ensign)'}
# ../../data/data_30_10/out/from_html/a33561c5.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02289', 'heading': 'Locating Tuition Due Dates', 'subheading': 'Where can I see the tuition payment due dates?', 'title': 'Locating Tuition Due Dates'}
# ../../data/data_30_10/out/from_html/e49f35bd.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01657', 'heading': 'Institute/Religion Course Information', 'subheading': 'What are the requirements for transferring Institute credits to BYU-Idaho or Ensign College as part of the Online Certificates and Degrees program?', 'title': 'Institute/Religion Course Information'}
# ../../data/data_30_10/out/from_html/7624cae3.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01705', 'heading': 'OD-DP: 2019 - Professional Studies', 'subheading': 'What is the course sequencing and graduation process for the Professional Studies degree program in 2019?', 'title': 'OD-DP: 2019 - Professional Studies'}
# ../../data/data_30_10/out/from_html/239ed5ce.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01161', 'heading': 'Student Record Privacy Policies (FERPA)', 'subheading': '.', 'title': 'Student Record Privacy Policies (FERPA)'}
# ../../data/data_30_10/out/from_html/231d0126.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01582', 'heading': 'Incorrect Bill Type', 'subheading': 'How do I know I have the correct bill type?I am being charged the wrong amount how do I fix it?', 'title': 'Incorrect Bill Type'}
# ../../data/data_30_10/out/from_html/5d967d83.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02297', 'heading': 'Viewing 1098T IRS Forms', 'subheading': 'How do I view my 1098T IRS forms?', 'title': 'Viewing 1098T IRS Forms'}
# ../../data/data_30_10/out/from_html/5a1c01b7.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02274', 'heading': 'Selecting a Gathering and Institute Time', 'subheading': 'How do I select my gathering and Institute time as a PC 101?', 'title': 'Selecting a Gathering and Institute Time'}
# ../../data/data_30_10/out/from_html/f15b6e01.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01712', 'heading': 'OD-DP: 2021 - Applied Health', 'subheading': 'What is the course sequencing and graduation process for the Applied Health degree program in 2021?', 'title': 'OD-DP: 2021 - Applied Health'}
# ../../data/data_30_10/out/from_html/51381a04.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01831', 'heading': 'OD-DP: 2024 - Communication (Ensign)', 'subheading': 'What is the course sequencing and graduation process for the Communication degree program in 2024?', 'title': 'OD-DP: 2024 - Communication (Ensign)'}
# ../../data/data_30_10/out/from_html/895b65e.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-01708', 'heading': 'OD-DP: 2020 - Applied Technology', 'subheading': 'What is the course sequencing and graduation process for the Applied Technology degree program in 2020?', 'title': 'OD-DP: 2020 - Applied Technology'}
# ../../data/data_30_10/out/from_html/cceb0a25.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02398', 'heading': "Church Leader Can't Find Endorsement", 'subheading': "What do I do if my Church Leader can't find my endorsement?", 'title': "Church Leader Can't Find Endorsement"}
# ../../data/data_30_10/out/from_html/8462bc40.md: {'url': 'https://help.byupathway.edu/knowledgebase/article/?kb=KA-02156', 'heading': 'Accessing Microsoft Office/Windows 2024', 'subheading': 'How to access/download Microsoft Office?', 'title': 'Accessing Microsoft Office/Windows 2024'}
# Metadata association completed.
#
# Attaching metadata to Markdown files...
# Metadata attached to ../../data/data_30_10/out/from_html/ef49f79c.md
# Metadata attached to ../../data/data_30_10/out/from_html/a54777de.md
# Metadata attached to ../../data/data_30_10/out/from_html/be7e9403.md
# Metadata attached to ../../data/data_30_10/out/from_html/3aa3d4dc.md
# Metadata attached to ../../data/data_30_10/out/from_html/865c5e97.md
# Metadata attached to ../../data/data_30_10/out/from_html/2c3ee33b.md
# Metadata attached to ../../data/data_30_10/out/from_html/32481663.md
# Metadata attached to ../../data/data_30_10/out/from_html/13648c09.md
# Metadata attached to ../../data/data_30_10/out/from_html/d5f03b64.md
# Metadata attached to ../../data/data_30_10/out/from_html/f0e158b8.md
# Metadata attached to ../../data/data_30_10/out/from_html/984ec70a.md
# Metadata attached to ../../data/data_30_10/out/from_html/b37fa482.md
# Metadata attached to ../../data/data_30_10/out/from_html/ffde8aee.md
# Metadata attached to ../../data/data_30_10/out/from_html/b537b281.md
# Metadata attached to ../../data/data_30_10/out/from_html/8d0019aa.md
# Metadata attached to ../../data/data_30_10/out/from_html/654f3f71.md
# Metadata attached to ../../data/data_30_10/out/from_html/708b64cd.md
# Metadata attached to ../../data/data_30_10/out/from_html/e4fb5978.md
# Metadata attached to ../../data/data_30_10/out/from_html/213fd3ba.md
# Metadata attached to ../../data/data_30_10/out/from_html/ba2e5084.md
# Metadata attached to ../../data/data_30_10/out/from_html/2dfc890c.md
# Metadata attached to ../../data/data_30_10/out/from_html/4e060077.md
# Metadata attached to ../../data/data_30_10/out/from_html/64f509c8.md
# Metadata attached to ../../data/data_30_10/out/from_html/c315500d.md
# Metadata attached to ../../data/data_30_10/out/from_html/4412a861.md
# Metadata attached to ../../data/data_30_10/out/from_html/cd296012.md
# Metadata attached to ../../data/data_30_10/out/from_html/336dc479.md
# Metadata attached to ../../data/data_30_10/out/from_html/c3f2e820.md
# Metadata attached to ../../data/data_30_10/out/from_html/fb2baad2.md
# Metadata attached to ../../data/data_30_10/out/from_html/448d4cc2.md
# Metadata attached to ../../data/data_30_10/out/from_html/34e7b84d.md
# Metadata attached to ../../data/data_30_10/out/from_html/dae9d961.md
# Metadata attached to ../../data/data_30_10/out/from_html/aa6495c3.md
# Metadata attached to ../../data/data_30_10/out/from_html/26367b66.md
# Metadata attached to ../../data/data_30_10/out/from_html/1d77ddb1.md
# Metadata attached to ../../data/data_30_10/out/from_html/169b1f88.md
# Metadata attached to ../../data/data_30_10/out/from_html/83134812.md
# Metadata attached to ../../data/data_30_10/out/from_html/619c2f1e.md
# Metadata attached to ../../data/data_30_10/out/from_html/2ec18992.md
# Metadata attached to ../../data/data_30_10/out/from_html/c3efabf.md
# Metadata attached to ../../data/data_30_10/out/from_html/dc46774f.md
# Metadata attached to ../../data/data_30_10/out/from_html/ef55c7d7.md
# Metadata attached to ../../data/data_30_10/out/from_html/1bfe43cc.md
# Metadata attached to ../../data/data_30_10/out/from_html/5afbb99a.md
# Metadata attached to ../../data/data_30_10/out/from_html/446af4ef.md
# Metadata attached to ../../data/data_30_10/out/from_html/dd63a555.md
# Metadata attached to ../../data/data_30_10/out/from_html/c55d460e.md
# Metadata attached to ../../data/data_30_10/out/from_html/a7e671aa.md
# Metadata attached to ../../data/data_30_10/out/from_html/c4789414.md
# Metadata attached to ../../data/data_30_10/out/from_html/e8405f40.md
# Metadata attached to ../../data/data_30_10/out/from_html/6f3ffba2.md
# Metadata attached to ../../data/data_30_10/out/from_html/201a01a0.md
# Metadata attached to ../../data/data_30_10/out/from_html/2a914d15.md
# Metadata attached to ../../data/data_30_10/out/from_html/31ff93e1.md
# Metadata attached to ../../data/data_30_10/out/from_html/5a645d39.md
# Metadata attached to ../../data/data_30_10/out/from_html/69b665df.md
# Metadata attached to ../../data/data_30_10/out/from_html/48232b45.md
# Metadata attached to ../../data/data_30_10/out/from_html/8b415e5d.md
# Metadata attached to ../../data/data_30_10/out/from_html/bd1df840.md
# Metadata attached to ../../data/data_30_10/out/from_html/ad0951da.md
# Metadata attached to ../../data/data_30_10/out/from_html/3f2d4a27.md
# Metadata attached to ../../data/data_30_10/out/from_html/6dd5f0b4.md
# Metadata attached to ../../data/data_30_10/out/from_html/aa1cc94d.md
# Metadata attached to ../../data/data_30_10/out/from_html/3f241bd3.md
# Metadata attached to ../../data/data_30_10/out/from_html/a7799509.md
# Metadata attached to ../../data/data_30_10/out/from_html/200631eb.md
# Metadata attached to ../../data/data_30_10/out/from_html/e55d5f8a.md
# Metadata attached to ../../data/data_30_10/out/from_html/123fa75.md
# Metadata attached to ../../data/data_30_10/out/from_html/982aabcf.md
# Metadata attached to ../../data/data_30_10/out/from_html/174545f4.md
# Metadata attached to ../../data/data_30_10/out/from_html/c979a495.md
# Metadata attached to ../../data/data_30_10/out/from_html/c36d0c83.md
# Metadata attached to ../../data/data_30_10/out/from_html/c2308217.md
# Metadata attached to ../../data/data_30_10/out/from_html/454f26f5.md
# Metadata attached to ../../data/data_30_10/out/from_html/8afb68e4.md
# Metadata attached to ../../data/data_30_10/out/from_html/6f47a72c.md
# Metadata attached to ../../data/data_30_10/out/from_html/60427562.md
# Metadata attached to ../../data/data_30_10/out/from_html/a2f70bf2.md
# Metadata attached to ../../data/data_30_10/out/from_html/b4f5d8b6.md
# Metadata attached to ../../data/data_30_10/out/from_html/2a76f538.md
# Metadata attached to ../../data/data_30_10/out/from_html/7b39ca29.md
# Metadata attached to ../../data/data_30_10/out/from_html/24ad7d0a.md
# Metadata attached to ../../data/data_30_10/out/from_html/fdfc5872.md
# Metadata attached to ../../data/data_30_10/out/from_html/c08db428.md
# Metadata attached to ../../data/data_30_10/out/from_html/ef2d9b59.md
# Metadata attached to ../../data/data_30_10/out/from_html/f123328f.md
# Metadata attached to ../../data/data_30_10/out/from_html/2e83d504.md
# Metadata attached to ../../data/data_30_10/out/from_html/9f476fd6.md
# Metadata attached to ../../data/data_30_10/out/from_html/13f2395e.md
# Metadata attached to ../../data/data_30_10/out/from_html/122c6322.md
# Metadata attached to ../../data/data_30_10/out/from_html/1f550f2d.md
# Metadata attached to ../../data/data_30_10/out/from_html/46f8a377.md
# Metadata attached to ../../data/data_30_10/out/from_html/aa832dee.md
# No metadata found for ../../data/data_30_10/out/from_html/b0832c62.md. Skipping.
# Metadata attached to ../../data/data_30_10/out/from_html/f64ef696.md
# Metadata attached to ../../data/data_30_10/out/from_html/7f9286c8.md
# Metadata attached to ../../data/data_30_10/out/from_html/6cf9735a.md
# Metadata attached to ../../data/data_30_10/out/from_html/de9f2db5.md
# Metadata attached to ../../data/data_30_10/out/from_html/7df208c2.md
# Metadata attached to ../../data/data_30_10/out/from_html/409fd4d3.md
# Metadata attached to ../../data/data_30_10/out/from_html/1f2d53a3.md
# Metadata attached to ../../data/data_30_10/out/from_html/716f3ea9.md
# Metadata attached to ../../data/data_30_10/out/from_html/cd90b4e2.md
# Metadata attached to ../../data/data_30_10/out/from_html/12480fe7.md
# Metadata attached to ../../data/data_30_10/out/from_html/b868eedd.md
# Metadata attached to ../../data/data_30_10/out/from_html/2b532722.md
# Metadata attached to ../../data/data_30_10/out/from_html/c8314bbe.md
# Metadata attached to ../../data/data_30_10/out/from_html/c49f2c39.md
# Metadata attached to ../../data/data_30_10/out/from_html/43e088db.md
# Metadata attached to ../../data/data_30_10/out/from_html/b3981caf.md
# Metadata attached to ../../data/data_30_10/out/from_html/2d1b3121.md
# Metadata attached to ../../data/data_30_10/out/from_html/338a7c54.md
# Metadata attached to ../../data/data_30_10/out/from_html/4da4e44a.md
# Metadata attached to ../../data/data_30_10/out/from_html/492998f8.md
# Metadata attached to ../../data/data_30_10/out/from_html/2d636daf.md
# Metadata attached to ../../data/data_30_10/out/from_html/13ee0915.md
# No metadata found for ../../data/data_30_10/out/from_html/53e8110a.md. Skipping.
# Metadata attached to ../../data/data_30_10/out/from_html/8fa84e2a.md
# Metadata attached to ../../data/data_30_10/out/from_html/68523fbb.md
# Metadata attached to ../../data/data_30_10/out/from_html/1838cb34.md
# Metadata attached to ../../data/data_30_10/out/from_html/a33561c5.md
# Metadata attached to ../../data/data_30_10/out/from_html/e49f35bd.md
# Metadata attached to ../../data/data_30_10/out/from_html/7624cae3.md
# Metadata attached to ../../data/data_30_10/out/from_html/239ed5ce.md
# Metadata attached to ../../data/data_30_10/out/from_html/231d0126.md
# Metadata attached to ../../data/data_30_10/out/from_html/5d967d83.md
# Metadata attached to ../../data/data_30_10/out/from_html/5a1c01b7.md
# Metadata attached to ../../data/data_30_10/out/from_html/f15b6e01.md
# Metadata attached to ../../data/data_30_10/out/from_html/51381a04.md
# Metadata attached to ../../data/data_30_10/out/from_html/895b65e.md
# Metadata attached to ../../data/data_30_10/out/from_html/cceb0a25.md
# Metadata attached to ../../data/data_30_10/out/from_html/8462bc40.md
# Metadata attachment completed.
#
# All tasks completed successfully.

# %%
# validate if the files are created and get a list of the files that are not created
files = os.listdir("../../data/data_30_10/out/from_html")
files_not_created = []
for index, row in df.iterrows():
    if f"{row['filename']}.md" not in files:
        files_not_created.append(row["URL"])

# find those files in the df and print them
df[df["URL"].isin(files_not_created)]
# Out:
# Empty DataFrame
# Columns: [URL, Section, Subsection, Title, filename]
# Index: []
